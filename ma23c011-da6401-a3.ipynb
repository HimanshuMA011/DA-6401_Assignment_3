# %%
# IMPORTANT: SOME KAGGLE DATA SOURCES ARE PRIVATE
# RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES.
import kagglehub
kagglehub.login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://www.kaggle.com/static/images/site-logo.png\nalt=\'Kaggle…
# Kaggle credentials set.
# Kaggle credentials successfully validated.

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

h1m4nshuj_dakshina_dataset_path = kagglehub.dataset_download('h1m4nshuj/dakshina-dataset')

print('Data source import complete.')
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/h1m4nshuj/dakshina-dataset?dataset_version_number=1...
# 100%|██████████| 284M/284M [00:14<00:00, 20.8MB/s]
# Extracting files...
# Data source import complete.

# %% [markdown]
# # DA6401 Assignment 3

# %%
# !pip install wandb
# !pip install wordcloud
# !pip install colour
# Out:
# Requirement already satisfied: wandb in /usr/local/lib/python3.11/dist-packages (0.19.9)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.11/dist-packages (from wandb) (8.1.8)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (3.1.44)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from wandb) (4.3.8)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (7.0.0)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.11.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from wandb) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.32.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.25.1)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.11/dist-packages (from wandb) (1.3.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from wandb) (75.2.0)
# Requirement already satisfied: typing-extensions<5,>=4.4 in /usr/local/lib/python3.11/dist-packages (from wandb) (4.13.2)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.17.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (2025.4.26)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.11/dist-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.11/dist-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from wordcloud) (11.1.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from wordcloud) (3.7.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.6.1->wordcloud) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.6.1->wordcloud) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.6.1->wordcloud) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.6.1->wordcloud) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.6.1->wordcloud) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.6.1->wordcloud) (2.4.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (25.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.6.1->wordcloud) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.6.1->wordcloud) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.6.1->wordcloud) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.6.1->wordcloud) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.6.1->wordcloud) (2024.2.0)
# Requirement already satisfied: colour in /usr/local/lib/python3.11/dist-packages (0.1.5)

# %%
## Installing font for Hindi for matplotlib ##
# !apt-get install -y fonts-lohit-deva
# !fc-list :lang=hi family
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-lohit-deva
# 0 upgraded, 1 newly installed, 0 to remove and 87 not upgraded.
# Need to get 78.9 kB of archives.
# After this operation, 198 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-lohit-deva all 2.95.4-4 [78.9 kB]
# Fetched 78.9 kB in 0s (644 kB/s)
# Selecting previously unselected package fonts-lohit-deva.
# (Reading database ... 129184 files and directories currently installed.)
# Preparing to unpack .../fonts-lohit-deva_2.95.4-4_all.deb ...
# Unpacking fonts-lohit-deva (2.95.4-4) ...
# Setting up fonts-lohit-deva (2.95.4-4) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Lohit Devanagari

# %%
# prompt: install tensorflow

# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.72.0rc1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow) (2.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<2.1.0,>=1.26.0->tensorflow) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<2.1.0,>=1.26.0->tensorflow) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy<2.1.0,>=1.26.0->tensorflow) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy<2.1.0,>=1.26.0->tensorflow) (2024.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy<2.1.0,>=1.26.0->tensorflow) (2024.2.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %%
import os
import random
import time
import wandb
import re, string
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
from wordcloud import WordCloud, STOPWORDS
from collections import Counter
from colour import Color
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

import tensorflow as tf
from tensorflow.keras import layers
import tensorflow.keras.backend as K
from tensorflow.keras.preprocessing.text import Tokenizer
# Out:
# 2025-05-18 23:22:21.623695: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747610541.835446      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747610541.895585      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Data Preprocessing

# %%
# Files with English to Devanagari (Hindi) translation word by word
# Punctutations have already been cleaned from this file

def get_data_files(language):
    """ Function fo read data
    """

    ## REPLACE THIS PATH UPTO dakshina_dataset_v1.0 with your own dataset path ##
    template = "/kaggle/input/dakshina-dataset-v1-0/{}/lexicons/{}.translit.sampled.{}.tsv"

    train_tsv = template.format(language, language, "train")
    val_tsv = template.format(language, language, "dev")
    test_tsv = template.format(language, language, "test")

    return train_tsv, val_tsv, test_tsv

## Utility functions for preprocessing data ##

def add_start_end_tokens(df, cols, sos="\t", eos="\n"):
    """ Adds EOS and SOS tokens to data
    """
    def add_tokens(s):
        # \t = starting token
        # \n = ending token
        return sos + str(s) + eos

    for col in cols:
        df[col] = df[col].apply(add_tokens)

def tokenize(lang, tokenizer=None):
    """ Uses tf.keras tokenizer to tokenize the data/words into characters
    """

    if tokenizer is None:
        tokenizer = Tokenizer(char_level=True)
        tokenizer.fit_on_texts(lang)

        lang_tensor = tokenizer.texts_to_sequences(lang)
        lang_tensor = tf.keras.preprocessing.sequence.pad_sequences(lang_tensor,
                                                            padding='post')

    else:
        lang_tensor = tokenizer.texts_to_sequences(lang)
        lang_tensor = tf.keras.preprocessing.sequence.pad_sequences(lang_tensor,
                                                            padding='post')

    return lang_tensor, tokenizer

def preprocess_data(fpath, input_lang_tokenizer=None, targ_lang_tokenizer=None):
    """ Reads, tokenizes and adds SOS/EOS tokens to data based on above functions
    """

    df = pd.read_csv(fpath, sep="\t", header=None)

    # adding start and end tokens to know when to stop predicting
    add_start_end_tokens(df, [0,1])

    input_lang_tensor, input_tokenizer = tokenize(df[1].astype(str).tolist(),
                                                    tokenizer=input_lang_tokenizer)

    targ_lang_tensor, targ_tokenizer = tokenize(df[0].astype(str).tolist(),
                                                    tokenizer=targ_lang_tokenizer)

    dataset = tf.data.Dataset.from_tensor_slices((input_lang_tensor, targ_lang_tensor))
    dataset = dataset.shuffle(len(dataset))

    return dataset, input_tokenizer, targ_tokenizer

# %% [markdown]
# # Model Building

# %%
import tensorflow as tf
from tensorflow.keras import layers

# ——— Utility: choose the right RNN layer ———
def get_rnn_layer(name, units, dropout, return_sequences, return_state):
    name = name.lower()
    if name == "rnn":
        return layers.SimpleRNN(units,
                                dropout=dropout,
                                return_sequences=return_sequences,
                                return_state=return_state)
    elif name == "gru":
        return layers.GRU(units,
                          dropout=dropout,
                          return_sequences=return_sequences,
                          return_state=return_state)
    elif name == "lstm":
        return layers.LSTM(units,
                           dropout=dropout,
                           return_sequences=return_sequences,
                           return_state=return_state)
    else:
        raise ValueError(f"Unsupported RNN type: {name}")

# ——— Optional Bahdanau Attention ———
class BahdanauAttention(layers.Layer):
    def __init__(self, units):
        super().__init__()
        self.W1 = layers.Dense(units)
        self.W2 = layers.Dense(units)
        self.V  = layers.Dense(1)

    def call(self, hidden_state, enc_output):
        # hidden_state: [batch, units]  or for LSTM, we concat [h, c]
        if isinstance(hidden_state, (list, tuple)):
            hidden = tf.concat(hidden_state, axis=-1)
        else:
            hidden = hidden_state
        # expand to [batch, 1, units*?]
        hidden_with_time = tf.expand_dims(hidden, 1)
        # score: [batch, seq_len, 1]
        score = self.V(tf.nn.tanh(self.W1(hidden_with_time) + self.W2(enc_output)))
        # attention_weights: [batch, seq_len, 1]
        attention_weights = tf.nn.softmax(score, axis=1)
        # context: [batch, units]
        context = tf.reduce_sum(attention_weights * enc_output, axis=1)
        return context, attention_weights

# ——— Encoder ———
class Encoder(tf.keras.Model):
    def __init__(self, layer_type, n_layers, units,
                 vocab_size, embedding_dim, dropout):
        super().__init__()
        self.layer_type = layer_type.lower()
        self.embedding = layers.Embedding(vocab_size, embedding_dim)

        # create n_layers RNN layers, all return_sequences & return_state
        self.rnns = [
            get_rnn_layer(layer_type, units, dropout,
                          return_sequences=True,
                          return_state=True)
            for _ in range(n_layers)
        ]

    def call(self, x, hidden):
        # x: [batch, seq_len]
        x = self.embedding(x)  # → [batch, seq_len, emb_dim]

        # First layer: pass initial_state
        first_rnn = self.rnns[0]
        if self.layer_type == "lstm":
            # returns (out, h, c)
            out, h, c = first_rnn(x, initial_state=hidden)
            state = [h, c]
        else:
            # GRU or SimpleRNN: returns (out, h)
            out, h = first_rnn(x, initial_state=hidden)
            state = h  # single tensor

        # Remaining layers: only pass the sequence, ignore their states
        for rnn in self.rnns[1:]:
            # each returns (out, state...), but we only need out
            outputs = rnn(out)
            out = outputs[0]

        # out: [batch, seq_len, units], state: either tensor or [h, c]
        return out, state

    def initialize_hidden_state(self, batch_size):
        if self.layer_type == "lstm":
            # return two tensors [h0, c0]
            return [tf.zeros((batch_size, self.rnns[0].units)),
                    tf.zeros((batch_size, self.rnns[0].units))]
        else:
            # return single tensor h0
            return tf.zeros((batch_size, self.rnns[0].units))

# ——— Decoder ———
class Decoder(tf.keras.Model):
    def __init__(self, layer_type, n_layers, units,
                 vocab_size, embedding_dim, dropout,
                 attention=False):
        super().__init__()
        self.layer_type = layer_type.lower()
        self.attention = attention

        self.embedding = layers.Embedding(vocab_size, embedding_dim)
        if attention:
            self.attn = BahdanauAttention(units)

        # For decoder we want: all but final layer return_sequences=True
        self.rnns = []
        for i in range(n_layers):
            return_seq = (i < n_layers - 1)
            self.rnns.append(
                get_rnn_layer(layer_type, units, dropout,
                              return_sequences=return_seq,
                              return_state=True)
            )

        # final projection
        self.fc = layers.Dense(vocab_size, activation="softmax")

    def call(self, x, hidden, enc_output=None):
        # x: [batch] or [batch, 1], we expect [batch, 1] time-step
        x = self.embedding(x)  # → [batch, 1, emb_dim]

        # apply attention to first layer only
        if self.attention and enc_output is not None:
            # hidden may be list (LSTM) or tensor (GRU/RNN)
            context, attn_w = self.attn(hidden, enc_output)
            # [batch, 1, emb_dim + units*?]
            x = tf.concat([tf.expand_dims(context, 1), x], axis=-1)
        else:
            attn_w = None

        # First RNN layer with initial state
        first_rnn = self.rnns[0]
        if self.layer_type == "lstm":
            out, h, c = first_rnn(x, initial_state=hidden)
            state = [h, c]
        else:
            out, h = first_rnn(x, initial_state=hidden)
            state = h  # single tensor

        # Remaining layers (no initial_state)
        for rnn in self.rnns[1:]:
            outputs = rnn(out)
            out = outputs[0]

        # out shape: [batch, units]  if last layer return_sequences=False
        logits = self.fc(out)  # → [batch, vocab_size]
        return logits, state, attn_w

# %%
class BeamSearch():
    def __init__(self, model, k):
        self.k = k
        self.model = model
        self.acc = tf.keras.metrics.Accuracy()

    def sample_beam_search(self, probs):

        m, n = probs.shape
        output_sequences = [[[], 0.0]]

        for row in probs:
            beams = []

            for tup in output_sequences:
                seq, score = tup
                for j in range(n):
                    new_beam = [seq + [j], score - tf.math.log(row[j])]
                    beams.append(new_beam)

            output_sequences = sorted(beams, key=lambda x: x[1])[:self.k]

        tensors, scores = list(zip(*output_sequences))
        tensors = list(map(lambda x: tf.expand_dims(tf.constant(x),0), tensors))

        return tf.concat(tensors, 0), scores

    def beam_accuracy(self, input, target):
        accs = []

        for i in range(self.k):
            self.acc.reset_state()
            self.acc.update_state(target, input[i, :])
            accs.append(self.acc.result())

        return max(accs)

    def step(self, input, target, enc_state):

        batch_acc = 0
        sequences = []

        enc_out, enc_state = self.model.encoder(input, enc_state)

        dec_state = enc_state
        dec_input = tf.expand_dims([self.model.targ_tokenizer.word_index["\t"]]*self.model.batch_size ,1)

        for t in range(1, target.shape[1]):

            preds, dec_state, _ = self.model.decoder(dec_input, dec_state, enc_out)

            sequences.append(preds)
            preds = tf.argmax(preds, 1)
            dec_input = tf.expand_dims(preds, 1)

        sequences = tf.concat(list(map(lambda x: tf.expand_dims(x, 1), sequences)), axis=1)

        for i in range(target.shape[0]):

            possibilities, scores = self.sample_beam_search(sequences[i, :, :])
            batch_acc += self.beam_accuracy(possibilities, target[i, 1:])

        batch_acc = batch_acc / target.shape[0]

        return 0, batch_acc

    def evaluate(self, test_dataset, batch_size=None, upto=5, use_wandb=False):

        if batch_size is not None:
            self.model.batch_size = batch_size
            test_dataset = test_dataset.batch(batch_size)
        else:
            self.model.batch_size = 1

        test_acc = 0
        enc_state = self.model.encoder.initialize_hidden_state(self.model.batch_size)

        for batch, (input, target) in enumerate(test_dataset.take(upto)):

           _, acc = self.step(input, target, enc_state)
           test_acc += acc

        if use_wandb:
            wandb.log({"test acc (beam search)": test_acc / upto})

        print(f"Test Accuracy on {upto*batch_size} samples: {test_acc / upto:.4f}\n")

    def translate(self, word):

        word = "\t" + word + "\n"
        sequences = []
        result = []

        inputs = self.model.input_tokenizer.texts_to_sequences([word])
        inputs = tf.keras.preprocessing.sequence.pad_sequences(inputs,
                                                               maxlen=self.model.max_input_len,
                                                               padding="post")


        enc_state = self.model.encoder.initialize_hidden_state(1)
        enc_out, enc_state = self.model.encoder(inputs, enc_state)

        dec_state = enc_state
        dec_input = tf.expand_dims([self.model.targ_tokenizer.word_index["\t"]]*1, 1)

        for t in range(1, self.model.max_target_len):

            preds, dec_state, _ = self.model.decoder(dec_input, dec_state, enc_out)

            sequences.append(preds)
            preds = tf.argmax(preds, 1)
            dec_input = tf.expand_dims(preds, 1)

        sequences = tf.concat(list(map(lambda x: tf.expand_dims(x, 1), sequences)), axis=1)

        possibilities, scores = self.sample_beam_search(tf.squeeze(sequences, 0))
        output_words = self.model.targ_tokenizer.sequences_to_texts(possibilities.numpy())

        def post_process(word):
            word = word.split(" ")[:-1]
            return "".join([x for x in word])

        output_words = list(map(post_process, output_words))

        return output_words, scores

# %%
class Seq2SeqModel():
    def __init__(self, embedding_dim, encoder_layers, decoder_layers, layer_type, units, dropout, attention=False):
        self.embedding_dim = embedding_dim
        self.encoder_layers = encoder_layers
        self.decoder_layers = decoder_layers


        self.layer_type = layer_type
        self.units = units
        self.dropout = dropout
        self.attention = attention
        self.stats = []
        self.batch_size = 128
        self.use_beam_search = False

    def save(self, path):
        self.encoder.save(path + "/encoder")
        self.decoder.save(path + "/decoder")
        # Optionally save tokenizers and other info as files (pickle/json) here

    @classmethod
    def load(cls, path, input_tokenizer, targ_tokenizer, max_input_len, max_target_len, custom_objects=None):
        encoder = tf.keras.models.load_model(path + "/encoder", custom_objects=custom_objects)
        decoder = tf.keras.models.load_model(path + "/decoder", custom_objects=custom_objects)
        return cls(encoder, decoder, input_tokenizer, targ_tokenizer, max_input_len, max_target_len)
    

    def build(self, loss, optimizer, metric):
        self.loss = loss
        self.optimizer = optimizer
        self.metric = metric

    def set_vocabulary(self, input_tokenizer, targ_tokenizer):
        self.input_tokenizer = input_tokenizer
        self.targ_tokenizer = targ_tokenizer
        self.create_model()

    def create_model(self):

        encoder_vocab_size = len(self.input_tokenizer.word_index) + 1
        decoder_vocab_size = len(self.targ_tokenizer.word_index) + 1

        self.encoder = Encoder(self.layer_type, self.encoder_layers, self.units, encoder_vocab_size,
                               self.embedding_dim, self.dropout)

        self.decoder = Decoder(self.layer_type, self.decoder_layers, self.units, decoder_vocab_size,
                               self.embedding_dim,  self.dropout, self.attention)

        # # when building:
        # self.encoder = Encoder(layer_type, encoder_layers, units,
        #                        encoder_vocab_size, embedding_dim, dropout)
        # self.decoder = Decoder(layer_type, decoder_layers, units,
        #                        decoder_vocab_size, embedding_dim, dropout,
        #                        attention=self.attention)

    @tf.function
    def train_step(self, input, target, enc_state):

        loss = 0

        with tf.GradientTape() as tape:

            enc_out, enc_state = self.encoder(input, enc_state)

            dec_state = enc_state
            dec_input = tf.expand_dims([self.targ_tokenizer.word_index["\t"]]*self.batch_size ,1)

            ## We use Teacher forcing to train the network
            ## Each target at timestep t is passed as input for timestep t + 1

            if random.random() < self.teacher_forcing_ratio:

                for t in range(1, target.shape[1]):

                    preds, dec_state, _ = self.decoder(dec_input, dec_state, enc_out)
                    loss += self.loss(target[:,t], preds)
                    self.metric.update_state(target[:,t], preds)

                    dec_input = tf.expand_dims(target[:,t], 1)

            else:

                for t in range(1, target.shape[1]):

                    preds, dec_state, _ = self.decoder(dec_input, dec_state, enc_out)
                    loss += self.loss(target[:,t], preds)
                    self.metric.update_state(target[:,t], preds)

                    preds = tf.argmax(preds, 1)
                    dec_input = tf.expand_dims(preds, 1)


            batch_loss = loss / target.shape[1]

            variables = self.encoder.variables + self.decoder.variables
            gradients = tape.gradient(loss, variables)

            self.optimizer.apply_gradients(zip(gradients, variables))

        return batch_loss, self.metric.result()

    @tf.function
    def validation_step(self, input, target, enc_state):

        loss = 0

        enc_out, enc_state = self.encoder(input, enc_state)

        dec_state = enc_state
        dec_input = tf.expand_dims([self.targ_tokenizer.word_index["\t"]]*self.batch_size ,1)

        for t in range(1, target.shape[1]):

            preds, dec_state, _ = self.decoder(dec_input, dec_state, enc_out)
            loss += self.loss(target[:,t], preds)
            self.metric.update_state(target[:,t], preds)

            preds = tf.argmax(preds, 1)
            dec_input = tf.expand_dims(preds, 1)

        batch_loss = loss / target.shape[1]

        return batch_loss, self.metric.result()


    def fit(self, dataset, val_dataset, batch_size=128, epochs=15, use_wandb=False, teacher_forcing_ratio=1.0):

        self.batch_size = batch_size
        self.teacher_forcing_ratio = teacher_forcing_ratio

        if use_wandb == True:
          run_name = (f"ed_{wandb.config.embedding_dim}_layers_{wandb.config.enc_dec_layers}_type_{wandb.config.layer_type}_"
                      f"units_{wandb.config.units}_dropout_{wandb.config.dropout}_attention_{wandb.config.attention}_"
                      f"beam_{wandb.config.beam_width}_tf_{wandb.config.teacher_forcing_ratio}")
          wandb.run.name = run_name

        steps_per_epoch = len(dataset) // self.batch_size
        steps_per_epoch_val = len(val_dataset) // self.batch_size

        dataset = dataset.batch(self.batch_size, drop_remainder=True)
        val_dataset = val_dataset.batch(self.batch_size, drop_remainder=True)

        # useful when we need to translate the sentence
        sample_inp, sample_targ = next(iter(dataset))
        self.max_target_len = sample_targ.shape[1]
        self.max_input_len = sample_inp.shape[1]

        template = "\nTrain Loss: {0:.4f} Train Accuracy: {1:.4f} Validation Loss: {2:.4f} Validation Accuracy: {3:.4f}"

        print("-"*100)
        for epoch in range(0, epochs):
            print(f"EPOCH {epoch}\n")

            ## Training loop ##
            total_loss = 0
            total_acc = 0
            self.metric.reset_state()

            starting_time = time.time()
            enc_state = self.encoder.initialize_hidden_state(self.batch_size)

            print("Training ...\n")
            for batch, (input, target) in enumerate(dataset.take(steps_per_epoch)):
                batch_loss, acc = self.train_step(input, target, enc_state)
                total_loss += batch_loss
                total_acc += acc


                if batch==0 or ((batch + 1) % 100 == 0):
                    print(f"Batch {batch+1} Loss {batch_loss:.4f}")

            avg_acc = total_acc / steps_per_epoch
            avg_loss = total_loss / steps_per_epoch

            # Validation loop ##
            total_val_loss = 0
            total_val_acc = 0
            self.metric.reset_state()

            enc_state = self.encoder.initialize_hidden_state(self.batch_size)

            print("\nValidating ...")
            for batch, (input, target) in enumerate(val_dataset.take(steps_per_epoch_val)):
                batch_loss, acc = self.validation_step(input, target, enc_state)
                total_val_loss += batch_loss
                total_val_acc += acc

            avg_val_acc = total_val_acc / steps_per_epoch_val
            avg_val_loss = total_val_loss / steps_per_epoch_val

            print(template.format(avg_loss, avg_acc*100, avg_val_loss, avg_val_acc*100))

            time_taken = time.time() - starting_time
            self.stats.append({"epoch": epoch,
                            "train_loss": avg_loss,
                            "dev_loss": avg_val_loss,
                            "train_acc": avg_acc,
                            "dev_acc": avg_val_acc,
                            # "training time": time_taken
                                      })

            if use_wandb:

                wandb.log(self.stats[-1])

            print(f"\nTime taken for the epoch {time_taken:.4f}")
            print("-"*100)

        print("\nModel trained successfully !!")

    def evaluate(self, test_dataset, batch_size=None):

        if batch_size is not None:
            self.batch_size = batch_size

        steps_per_epoch_test = len(test_dataset) // batch_size
        test_dataset = test_dataset.batch(batch_size, drop_remainder=True)

        total_test_loss = 0
        total_test_acc = 0
        self.metric.reset_state()

        enc_state = self.encoder.initialize_hidden_state(self.batch_size)

        print("\nRunning test dataset through the model...\n")
        for batch, (input, target) in enumerate(test_dataset.take(steps_per_epoch_test)):
            batch_loss, acc = self.validation_step(input, target, enc_state)
            total_test_loss += batch_loss
            total_test_acc += acc

        avg_test_acc = total_test_acc / steps_per_epoch_test
        avg_test_loss = total_test_loss / steps_per_epoch_test

        print(f"Test Loss: {avg_test_loss:.4f} Test Accuracy: {avg_test_acc:.4f}")

        return avg_test_loss, avg_test_acc


    def translate(self, word, get_heatmap=False):

        word = "\t" + word + "\n"

        inputs = self.input_tokenizer.texts_to_sequences([word])
        inputs = tf.keras.preprocessing.sequence.pad_sequences(inputs,
                                                               maxlen=self.max_input_len,
                                                               padding="post")

        result = ""
        att_wts = []

        enc_state = self.encoder.initialize_hidden_state(1)
        enc_out, enc_state = self.encoder(inputs, enc_state)

        dec_state = enc_state
        dec_input = tf.expand_dims([self.targ_tokenizer.word_index["\t"]]*1, 1)

        for t in range(1, self.max_target_len):

            preds, dec_state, attention_weights = self.decoder(dec_input, dec_state, enc_out)

            if get_heatmap:
                att_wts.append(attention_weights)

            preds = tf.argmax(preds, 1)
            next_char = self.targ_tokenizer.index_word[preds.numpy().item()]
            result += next_char

            dec_input = tf.expand_dims(preds, 1)

            if next_char == "\n":
                return result[:-1], att_wts[:-1]

        return result[:-1], att_wts[:-1]

    def plot_attention_heatmap(self, word, ax, font_path="/usr/share/fonts/truetype/lohit-devanagari/Lohit-Devanagari.ttf"):

        translated_word, attn_wts = self.translate(word, get_heatmap=True)
        attn_heatmap = tf.squeeze(tf.concat(attn_wts, 0), -1).numpy()

        input_word_len = len(word)
        output_word_len = len(translated_word)

        ax.imshow(attn_heatmap[:, :input_word_len])

        font_prop = FontProperties(fname=font_path, size=18)

        ax.set_xticks(np.arange(input_word_len))
        ax.set_yticks(np.arange(output_word_len))

        ax.set_xticklabels(list(word))
        ax.set_yticklabels(list(translated_word), fontproperties=font_prop)

# %% [markdown]
# # Visualizing Model Outputs

# %%
def get_colors(inputs, targets, preds):

    n = len(targets)
    smoother = SmoothingFunction().method2
    def get_scores(target, output, smoother):
        return sentence_bleu(list(list(target)), list(output), smoothing_function=smoother)

    red = Color("red")
    colors = list(red.range_to(Color("violet"),n))
    colors = list(map(lambda c: c.hex, colors))

    scores = []
    for i in range(n):
        scores.append(get_scores(targets[i], preds[i], smoother))

    d = dict(zip(sorted(scores), list(range(n))))
    ordered_colors = list(map(lambda x: colors[d[x]], scores))

    input_colors = dict(zip(inputs, ordered_colors))
    target_colors = dict(zip(targets, ordered_colors))
    pred_colors = dict(zip(preds, ordered_colors))

    return input_colors, target_colors, pred_colors


class Colorizer():
    def __init__(self, word_to_color, default_color):

        self.word_to_color = word_to_color
        self.default_color = default_color

    def __call__(self, word, **kwargs):
        return self.word_to_color.get(word, self.default_color)

def randomly_evaluate(model, test_file=get_data_files("hi")[2], n=10):

    df = pd.read_csv(test_file, sep="\t", header=None)
    df = df.sample(n=n).reset_index(drop=True)

    print(f"Randomly evaluating the model on {n} words\n")

    for i in range(n):
        word = str(df[1][i])

        print(f"Input word: {word}")
        print(f"Actual translation: {str(df[0][i])}")
        print(f"Model translation: {model.translate(word)[0]}\n")

def visualize_model_outputs(model, test_file=get_data_files("hi")[2], n=10, font_path="/usr/share/fonts/truetype/lohit-devanagari/Lohit-Devanagari.ttf"):

    df = pd.read_csv(test_file, sep="\t", header=None)
    df = df.sample(n=n).reset_index(drop=True)

    inputs = df[1].astype(str).tolist()
    targets = df[0].astype(str).tolist()
    preds = list(map(lambda word: model.translate(word)[0], inputs))

    # Generate colors for the words
    input_colors, target_colors, pred_colors =  get_colors(inputs, targets, preds)
    color_fn_ip = Colorizer(input_colors, "white")
    color_fn_tr = Colorizer(target_colors, "white")
    color_fn_op = Colorizer(pred_colors, "white")

    input_text = Counter(inputs)
    target_text = Counter(targets)
    output_text = Counter(preds)

    fig, axs = plt.subplots(1,3, figsize=(30, 15))
    plt.tight_layout()

    wc_in = WordCloud(random_state=1).generate_from_frequencies(input_text)
    wc_out = WordCloud(font_path=font_path, random_state=1).generate_from_frequencies(output_text)
    wc_tar = WordCloud(font_path=font_path, random_state=1).generate_from_frequencies(target_text)

    axs[0].set_title("Input words", fontsize=30)
    axs[0].imshow(wc_in.recolor(color_func=color_fn_ip))
    axs[1].set_title("Target words", fontsize=30)
    axs[1].imshow(wc_tar.recolor(color_func=color_fn_tr))
    axs[2].set_title("Model outputs", fontsize=30)
    axs[2].imshow(wc_out.recolor(color_func=color_fn_op))
    plt.show()



def test_on_dataset(language, embedding_dim, encoder_layers, decoder_layers, layer_type, units, dropout, attention, teacher_forcing_ratio=1.0, save_outputs=None):

    TRAIN_TSV, VAL_TSV, TEST_TSV = get_data_files(language)

    model = Seq2SeqModel(embedding_dim,
                         encoder_layers,
                         decoder_layers,
                         layer_type,
                         units,
                         dropout,
                         attention)

    dataset, input_tokenizer, targ_tokenizer = preprocess_data(TRAIN_TSV)
    val_dataset, _, _ = preprocess_data(VAL_TSV, input_tokenizer, targ_tokenizer)

    model.set_vocabulary(input_tokenizer, targ_tokenizer)
    model.build(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                optimizer = tf.keras.optimizers.Adam(),
                metric = tf.keras.metrics.SparseCategoricalAccuracy())

    model.fit(dataset, val_dataset, epochs=10, use_wandb=False, teacher_forcing_ratio=teacher_forcing_ratio)

    ## Character level accuracy ##
    test_dataset, _, _ = preprocess_data(TEST_TSV, model.input_tokenizer, model.targ_tokenizer)
    test_loss, test_acc = model.evaluate(test_dataset, batch_size=100)

    ##  Word level accuracy ##
    test_tsv = pd.read_csv(TEST_TSV, sep="\t", header=None)
    inputs = test_tsv[1].astype(str).tolist()
    targets = test_tsv[0].astype(str).tolist()

    outputs = []

    for word in inputs:
        outputs.append(model.translate(word)[0])

    def word_level_acc(outputs, targets):
        return np.sum(np.asarray(outputs) == np.array(targets)) / len(outputs)

    print(f"Word level accuracy: {word_level_acc(outputs, targets)}")

    if save_outputs is not None:
        df = pd.DataFrame()
        df["inputs"] = inputs
        df["targets"] = targets
        df["outputs"] = outputs
        df.to_csv(save_outputs)


    return model

#randomly_evaluate(model, n=15)

# %% [markdown]
# # Visualizing Model Connectivity (Q6)

# %%
# Tools for getting model connectivity between input and output characters
def get_lstm_output(decoder, x, hidden, enc_out=None):

    x = decoder.embedding(x)

    if decoder.attention:
        context_vector, attention_weights = decoder.attention_layer(hidden, enc_out)
        x = tf.concat([tf.expand_dims(context_vector, 1), x], -1)
    else:
        attention_weights = None

    x = decoder.rnns[0](x, initial_state=hidden)

    for layer in decoder.rnns[1:]:
        if isinstance(x, tuple):
            x = x[0]  # Extract the output, discard hidden state for intermediate layers
        x = layer(x)

    output, state = x[0], x[1:]

    #output = decoder.dense(decoder.flatten(output))

    return output, state, attention_weights

def get_output_from_embedding(encoder, x, hidden):

    x = encoder.rnns[0](x, initial_state=hidden)

    for layer in encoder.rnns[1:]:
        if isinstance(x, tuple):
            x = x[0]  # Extract the output, discard hidden state for intermediate layers
        x = layer(x)

    output, state = x[0], x[1:]

    return output, state


def get_connectivity(model, word):

    word = "\t" + word + "\n"

    inputs = model.input_tokenizer.texts_to_sequences([word])
    inputs = tf.keras.preprocessing.sequence.pad_sequences(inputs,
                                                            maxlen=model.max_input_len,
                                                            padding="post")

    result = ""

    gradient_list = []

    enc_state = model.encoder.initialize_hidden_state(1)
    embedded_in = model.encoder.embedding(inputs)


    with tf.GradientTape(persistent=True, watch_accessed_variables=False) as tape:
        tape.watch(embedded_in)

        enc_out, enc_state = get_output_from_embedding(model.encoder, embedded_in, enc_state)

        dec_state = enc_state
        dec_input = tf.expand_dims([model.targ_tokenizer.word_index["\t"]]*1, 1)

        for t in range(1, model.max_target_len):

            lstm_out, dec_state, _ = get_lstm_output(model.decoder, dec_input, dec_state, enc_out)

            preds = model.decoder.fc(lstm_out)
            gradient_list.append(tape.gradient(lstm_out, embedded_in)[0])

            preds = tf.argmax(preds, 1)
            # Safe dictionary access with a fallback
            pred_idx = preds.numpy().item()
            next_char = model.targ_tokenizer.index_word.get(pred_idx, "?")

            result += next_char

            dec_input = tf.expand_dims(preds, 1)

            if next_char == "\n":
                return result[:-1], gradient_list[:-1]

        return result[:-1], gradient_list[:-1]

# %%
# Imports for visualising the model connectivity
from sklearn.preprocessing import MinMaxScaler

from IPython.display import HTML as html_print
from IPython.display import display

# get html element
def cstr(s, color='black'):
    if s == ' ':
      return "<text style=color:#000;padding-left:10px;background-color:{}> </text>".format(color, s)
    else:
      return "<text style=color:#000;background-color:{}>{} </text>".format(color, s)

# print html
def print_color(t):
	  display(html_print(''.join([cstr(ti, color=ci) for ti,ci in t])))

# get appropriate color for value
def get_clr(value):
    colors = ['#85c2e1', '#89c4e2', '#95cae5', '#99cce6', '#a1d0e8'
      '#b2d9ec', '#baddee', '#c2e1f0', '#eff7fb', '#f9e8e8',
      '#f9e8e8', '#f9d4d4', '#f9bdbd', '#f8a8a8', '#f68f8f',
      '#f47676', '#f45f5f', '#f34343', '#f33b3b', '#f42e2e']
    value = int(value * 19)
    if value == 19:
        value -= 1
    return colors[value]

# sigmoid function
def sigmoid(x):
    z = 1/(1 + np.exp(-x))
    return z

def softmax(x):
    v = np.exp(x)
    v = v / np.sum(v)
    return v

def get_gradient_norms(grad_list, word, activation="sigmoid"):
    grad_norms = []
    for grad_tensor in grad_list:
        grad_mags = tf.norm(grad_tensor, axis=1)
        grad_mags = grad_mags[:len(word)]
        if activation == "softmax":
            grad_mags_scaled = softmax(grad_mags)
        elif activation == "scaler":
            scaler = MinMaxScaler()
            grad_mags = tf.reshape(grad_mags, (-1,1))
            grad_mags_scaled = scaler.fit_transform(grad_mags)
        else:
            grad_mags_scaled = sigmoid(grad_mags)
        grad_norms.append(grad_mags_scaled)
    return grad_norms

def visualize(grad_norms, word, translated_word):
    print("Original Word:", word)
    print("Transliterated Word:", translated_word)
    for i in range(len(translated_word)):
        print("Connectivity Visualization for", translated_word[i],":")
        text_colours = []
        for j in range(len(grad_norms[i])):
            text = (word[j], get_clr(grad_norms[i][j]))
            text_colours.append(text)
        print_color(text_colours)

def visualise_connectivity(model, word, activation="sigmoid"):
    translated_word, grad_list = get_connectivity(model, word)
    grad_norms = get_gradient_norms(grad_list, word, activation)
    visualize(grad_norms, word, translated_word)

# %%
model = test_on_dataset(language="hi",
                        embedding_dim=256,
                        encoder_layers=3,
                        decoder_layers=3,
                        layer_type="lstm",
                        units=256,
                        dropout=0.2,
                        attention=False)
# Out:
# I0000 00:00:1747610625.318480      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1747610625.319237      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# ----------------------------------------------------------------------------------------------------
# EPOCH 0
#
# Training ...
# /usr/local/lib/python3.11/dist-packages/keras/src/optimizers/base_optimizer.py:774: UserWarning: Gradients do not exist for variables ['seed_generator/seed_generator_state', 'encoder/lstm_1/lstm_cell/kernel', 'encoder/lstm_1/lstm_cell/recurrent_kernel', 'encoder/lstm_1/lstm_cell/bias', 'seed_generator_1/seed_generator_state', 'encoder/lstm_2/lstm_cell/kernel', 'encoder/lstm_2/lstm_cell/recurrent_kernel', 'encoder/lstm_2/lstm_cell/bias', 'seed_generator_2/seed_generator_state', 'seed_generator_3/seed_generator_state', 'seed_generator_4/seed_generator_state', 'seed_generator_5/seed_generator_state'] when minimizing the loss. If using `model.compile()`, did you forget to provide a `loss` argument?
#   warnings.warn(
# I0000 00:00:1747610666.591124     102 cuda_dnn.cc:529] Loaded cuDNN version 90300
# Batch 1 Loss 3.9899
# Batch 100 Loss 1.0940
# Batch 200 Loss 1.0033
# Batch 300 Loss 1.0133
#
# Validating ...
#
# Train Loss: 1.1328 Train Accuracy: 66.7548 Validation Loss: 2.2956 Validation Accuracy: 52.9785
#
# Time taken for the epoch 68.6699
# ----------------------------------------------------------------------------------------------------
# EPOCH 1
#
# Training ...
#
# Batch 1 Loss 0.9680
# Batch 100 Loss 0.9151
# Batch 200 Loss 0.9046
# Batch 300 Loss 0.8490
#
# Validating ...
#
# Train Loss: 0.9101 Train Accuracy: 73.3828 Validation Loss: 2.2736 Validation Accuracy: 54.6120
#
# Time taken for the epoch 18.3508
# ----------------------------------------------------------------------------------------------------
# EPOCH 2
#
# Training ...
#
# Batch 1 Loss 0.9099
# Batch 100 Loss 0.8604
# Batch 200 Loss 0.7652
# Batch 300 Loss 0.8399
#
# Validating ...
#
# Train Loss: 0.8110 Train Accuracy: 75.3366 Validation Loss: 2.2676 Validation Accuracy: 56.2849
#
# Time taken for the epoch 18.5601
# ----------------------------------------------------------------------------------------------------
# EPOCH 3
#
# Training ...
#
# Batch 1 Loss 0.7509
# Batch 100 Loss 0.7322
# Batch 200 Loss 0.7340
# Batch 300 Loss 0.6333
#
# Validating ...
#
# Train Loss: 0.6651 Train Accuracy: 78.7555 Validation Loss: 2.1571 Validation Accuracy: 60.3915
#
# Time taken for the epoch 18.5843
# ----------------------------------------------------------------------------------------------------
# EPOCH 4
#
# Training ...
#
# Batch 1 Loss 0.5905
# Batch 100 Loss 0.5194
# Batch 200 Loss 0.5025
# Batch 300 Loss 0.4454
#
# Validating ...
#
# Train Loss: 0.5048 Train Accuracy: 82.6150 Validation Loss: 1.8444 Validation Accuracy: 67.3658
#
# Time taken for the epoch 18.3990
# ----------------------------------------------------------------------------------------------------
# EPOCH 5
#
# Training ...
#
# Batch 1 Loss 0.4352
# Batch 100 Loss 0.3886
# Batch 200 Loss 0.3765
# Batch 300 Loss 0.3460
#
# Validating ...
#
# Train Loss: 0.3755 Train Accuracy: 86.8777 Validation Loss: 1.5927 Validation Accuracy: 72.8638
#
# Time taken for the epoch 18.6771
# ----------------------------------------------------------------------------------------------------
# EPOCH 6
#
# Training ...
#
# Batch 1 Loss 0.3373
# Batch 100 Loss 0.2882
# Batch 200 Loss 0.3307
# Batch 300 Loss 0.2697
#
# Validating ...
#
# Train Loss: 0.2959 Train Accuracy: 89.7287 Validation Loss: 1.5342 Validation Accuracy: 75.8289
#
# Time taken for the epoch 18.3795
# ----------------------------------------------------------------------------------------------------
# EPOCH 7
#
# Training ...
#
# Batch 1 Loss 0.2358
# Batch 100 Loss 0.2390
# Batch 200 Loss 0.2757
# Batch 300 Loss 0.2262
#
# Validating ...
#
# Train Loss: 0.2471 Train Accuracy: 91.3962 Validation Loss: 1.5118 Validation Accuracy: 77.1494
#
# Time taken for the epoch 18.7669
# ----------------------------------------------------------------------------------------------------
# EPOCH 8
#
# Training ...
#
# Batch 1 Loss 0.2068
# Batch 100 Loss 0.2228
# Batch 200 Loss 0.1998
# Batch 300 Loss 0.2258
#
# Validating ...
#
# Train Loss: 0.2174 Train Accuracy: 92.5104 Validation Loss: 1.4567 Validation Accuracy: 78.3196
#
# Time taken for the epoch 18.5691
# ----------------------------------------------------------------------------------------------------
# EPOCH 9
#
# Training ...
#
# Batch 1 Loss 0.2002
# Batch 100 Loss 0.1933
# Batch 200 Loss 0.1929
# Batch 300 Loss 0.1704
#
# Validating ...
#
# Train Loss: 0.1972 Train Accuracy: 93.1292 Validation Loss: 1.4328 Validation Accuracy: 79.0964
#
# Time taken for the epoch 18.6650
# ----------------------------------------------------------------------------------------------------
#
# Model trained successfully !!
#
# Running test dataset through the model...
#
# Test Loss: 1.3145 Test Accuracy: 0.8131
# Word level accuracy: 0.2665482007996446

# %%
visualize_model_outputs(model, n=20)

# %%
def get_test_words(n):
    test_df = pd.read_csv(get_data_files("hi")[2])
    test_sample = test_df.sample(n)
    test_sample.reset_index(inplace=True, drop=True)
    test_words = []
    for i in test_sample.index:
        entry = test_sample["अंक\tank\t5"].loc[i]
        parts = entry.split("\t")
        word = parts[1]
        test_words.append(word)
    return test_words

test_words = get_test_words(5)
print(test_words)
# Out:
# ['garibi', 'sahuuliyata', 'sthitiyaan', 'saunpane', 'bandhuon']

# %%
for word in test_words:
    visualise_connectivity(model, word, activation="scaler")
# Out:
# Original Word: garibi
# Transliterated Word: वलांपनपीपायउक्द????
# Connectivity Visualization for व :
# /tmp/ipykernel_35/2546086063.py:24: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   value = int(value * 19)
# <text style=color:#000;background-color:#85c2e1>g </text><text style=color:#000;background-color:#f34343>a </text><text style=color:#000;background-color:#f47676>r </text><text style=color:#000;background-color:#f68f8f>i </text><text style=color:#000;background-color:#f9d4d4>b </text><text style=color:#000;background-color:#f42e2e>i </text>
# Connectivity Visualization for ल :
# <text style=color:#000;background-color:#85c2e1>g </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>r </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>i </text>
# Connectivity Visualization for ा :
# <text style=color:#000;background-color:#85c2e1>g </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>r </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>i </text>
# Connectivity Visualization for ं :
# <text style=color:#000;background-color:#85c2e1>g </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>r </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>i </text>
# Connectivity Visualization for प :
# <text style=color:#000;background-color:#85c2e1>g </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>r </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>i </text>
# Connectivity Visualization for न :
# <text style=color:#000;background-color:#85c2e1>g </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>r </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>i </text>
# Connectivity Visualization for प :
# <text style=color:#000;background-color:#85c2e1>g </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>r </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>i </text>
# Connectivity Visualization for ी :
# <text style=color:#000;background-color:#85c2e1>g </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>r </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>i </text>
# Connectivity Visualization for प :
# <text style=color:#000;background-color:#85c2e1>g </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>r </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>i </text>
# Connectivity Visualization for ा :
# <text style=color:#000;background-color:#85c2e1>g </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>r </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>i </text>
# Connectivity Visualization for य :
# <text style=color:#000;background-color:#85c2e1>g </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>r </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>i </text>
# Connectivity Visualization for उ :
# <text style=color:#000;background-color:#85c2e1>g </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>r </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>i </text>
# Connectivity Visualization for क :
# <text style=color:#000;background-color:#85c2e1>g </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>r </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>i </text>
# Connectivity Visualization for ् :
# <text style=color:#000;background-color:#85c2e1>g </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>r </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>i </text>
# Connectivity Visualization for द :
# <text style=color:#000;background-color:#85c2e1>g </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>r </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>i </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>g </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>r </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>i </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>g </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>r </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>i </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>g </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>r </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>i </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>g </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>r </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>i </text>
# Original Word: sahuuliyata
# Transliterated Word: स??????????????????
# Connectivity Visualization for स :
# /tmp/ipykernel_35/2546086063.py:24: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   value = int(value * 19)
# <text style=color:#000;background-color:#f45f5f>s </text><text style=color:#000;background-color:#f42e2e>a </text><text style=color:#000;background-color:#f9e8e8>h </text><text style=color:#000;background-color:#f68f8f>u </text><text style=color:#000;background-color:#f47676>u </text><text style=color:#000;background-color:#f47676>l </text><text style=color:#000;background-color:#f9e8e8>i </text><text style=color:#000;background-color:#f9e8e8>y </text><text style=color:#000;background-color:#c2e1f0>a </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#f9bdbd>a </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>l </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>y </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>a </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>l </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>y </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>a </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>l </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>y </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>a </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>l </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>y </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>a </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>l </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>y </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>a </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>l </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>y </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>a </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>l </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>y </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>a </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>l </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>y </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>a </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>l </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>y </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>a </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>l </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>y </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>a </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>l </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>y </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>a </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>l </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>y </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>a </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>l </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>y </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>a </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>l </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>y </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>a </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>l </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>y </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>a </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>l </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>y </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>a </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>l </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>y </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>a </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>l </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>y </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>a </text>
# Original Word: sthitiyaan
# Transliterated Word: तमतागुद्ब्ध????????
# Connectivity Visualization for त :
# /tmp/ipykernel_35/2546086063.py:24: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   value = int(value * 19)
# <text style=color:#000;background-color:#f9e8e8>s </text><text style=color:#000;background-color:#f8a8a8>t </text><text style=color:#000;background-color:#f42e2e>h </text><text style=color:#000;background-color:#f9e8e8>i </text><text style=color:#000;background-color:#f9d4d4>t </text><text style=color:#000;background-color:#f9e8e8>i </text><text style=color:#000;background-color:#eff7fb>y </text><text style=color:#000;background-color:#99cce6>a </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for म :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>y </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for त :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>y </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for ा :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>y </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for ग :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>y </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for ु :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>y </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for द :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>y </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for ् :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>y </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for ब :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>y </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for ् :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>y </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for ध :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>y </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>y </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>y </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>y </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>y </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>y </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>y </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>y </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>y </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text>
# Original Word: saunpane
# Transliterated Word: भताश???????????????
# Connectivity Visualization for भ :
# /tmp/ipykernel_35/2546086063.py:24: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   value = int(value * 19)
# <text style=color:#000;background-color:#99cce6>s </text><text style=color:#000;background-color:#f9e8e8>a </text><text style=color:#000;background-color:#99cce6>u </text><text style=color:#000;background-color:#c2e1f0>n </text><text style=color:#000;background-color:#f9bdbd>p </text><text style=color:#000;background-color:#f42e2e>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#99cce6>e </text>
# Connectivity Visualization for त :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>p </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>e </text>
# Connectivity Visualization for ा :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>p </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>e </text>
# Connectivity Visualization for श :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>p </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>e </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>p </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>e </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>p </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>e </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>p </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>e </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>p </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>e </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>p </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>e </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>p </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>e </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>p </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>e </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>p </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>e </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>p </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>e </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>p </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>e </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>p </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>e </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>p </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>e </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>p </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>e </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>p </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>e </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>p </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>e </text>
# Original Word: bandhuon
# Transliterated Word: पनपाप्ध????????????
# Connectivity Visualization for प :
# /tmp/ipykernel_35/2546086063.py:24: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   value = int(value * 19)
# <text style=color:#000;background-color:#95cae5>b </text><text style=color:#000;background-color:#a1d0e8#b2d9ec>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#f9d4d4>d </text><text style=color:#000;background-color:#f42e2e>h </text><text style=color:#000;background-color:#eff7fb>u </text><text style=color:#000;background-color:#a1d0e8#b2d9ec>o </text><text style=color:#000;background-color:#95cae5>n </text>
# Connectivity Visualization for न :
# <text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>d </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>o </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for प :
# <text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>d </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>o </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for ा :
# <text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>d </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>o </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for प :
# <text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>d </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>o </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for ् :
# <text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>d </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>o </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for ध :
# <text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>d </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>o </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>d </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>o </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>d </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>o </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>d </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>o </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>d </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>o </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>d </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>o </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>d </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>o </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>d </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>o </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>d </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>o </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>d </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>o </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>d </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>o </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>d </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>o </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for ? :
# <text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>d </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>u </text><text style=color:#000;background-color:#85c2e1>o </text><text style=color:#000;background-color:#85c2e1>n </text>

# %%
randomly_evaluate(model, n=5)
# Out:
# Randomly evaluating the model on 5 words
#
# Input word: baramade
# Actual translation: बरामदे
# Model translation: बरमाड़े
#
# Input word: naivegh
# Actual translation: नैवेद्य
# Model translation: नैवेंग
#
# Input word: asamaany
# Actual translation: असमान्य
# Model translation: असमान्य
#
# Input word: jivaniyan
# Actual translation: जीवनियां
# Model translation: जीवानिया
#
# Input word: rahmat
# Actual translation: रहमत
# Model translation: रहमत

# %%
word = "\t" + "bablu" + "\n"
inputs = model.input_tokenizer.texts_to_sequences([word])
inputs = tf.keras.preprocessing.sequence.pad_sequences(
    inputs, maxlen=model.max_input_len, padding="post"
)

# Initialize the hidden state
enc_state = model.encoder.initialize_hidden_state(1)

# Directly use the encoder model
enc_out, enc_state = model.encoder(inputs, enc_state)

# Prepare the decoder input
dec_input = tf.expand_dims([model.targ_tokenizer.word_index["\t"]], 1)
dec_state = enc_state
result = ""

for t in range(1, model.max_target_len):
    # Get the decoder output
    logits, dec_state, _ = model.decoder(dec_input, dec_state, enc_out)

    # Choose the highest probability token
    pred = tf.argmax(logits, axis=1).numpy().item()

    # Map to word and update result
    next_char = model.targ_tokenizer.index_word.get(pred, "?")
    result += next_char

    # Update the decoder input
    dec_input = tf.expand_dims([pred], 1)

    # Stop if end token is predicted
    if next_char == "\n":
        break

print(f"Predicted output: {result}")
# Out:
# Predicted output: बाबलु

# %% [markdown]
# # WandB Function

# %%
wandb.login()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: ma23c011 (ma23c011-indian-institute-of-technology-madras) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
def train_with_wandb(language, test_beam_search=False):

    config_defaults = {"embedding_dim": 64,
                       "enc_dec_layers": 1,
                       "layer_type": "lstm",
                       "units": 128,
                       "dropout": 0,
                       "attention": False,
                       "beam_width": 3,
                       "teacher_forcing_ratio": 1.0
                       }

    wandb.init(config=config_defaults, project="transliteration-sweep", resume=True)
    # Below is an example of a custom run name for sweep 4
    # This line was different for all sweeps
    #wandb.run.name = f"beam_width_{wandb.config.beam_width}"

    ## 1. SELECT LANGUAGE ##
    TRAIN_TSV, VAL_TSV, TEST_TSV = get_data_files(language)

    ## 2. DATA PREPROCESSING ##
    dataset, input_tokenizer, targ_tokenizer = preprocess_data(TRAIN_TSV)
    val_dataset, _, _ = preprocess_data(VAL_TSV, input_tokenizer, targ_tokenizer)

    ## 3. CREATING THE MODEL ##
    model = Seq2SeqModel(embedding_dim=wandb.config.embedding_dim,
                         encoder_layers=wandb.config.enc_dec_layers,
                         decoder_layers=wandb.config.enc_dec_layers,
                         layer_type=wandb.config.layer_type,
                         units=wandb.config.units,
                         dropout=wandb.config.dropout,
                         attention=wandb.config.attention)

    ## 4. COMPILING THE MODEL
    model.set_vocabulary(input_tokenizer, targ_tokenizer)
    model.build(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                optimizer = tf.keras.optimizers.Adam(),
                metric = tf.keras.metrics.SparseCategoricalAccuracy())

    ## 5. FITTING AND VALIDATING THE MODEL
    model.fit(dataset, val_dataset, epochs=20, use_wandb=True, teacher_forcing_ratio=wandb.config.teacher_forcing_ratio)

    if test_beam_search:
        ## OPTIONAL :- Evaluate the dataset using beam search and without beam search
        val_dataset, _, _ = preprocess_data(VAL_TSV, model.input_tokenizer, model.targ_tokenizer)
        subset = val_dataset.take(500)

        # a) Without beam search
        _, test_acc_without = model.evaluate(subset, batch_size=100)
        wandb.log({"test acc": test_acc_without})

        # b) With beam search
        beam_search = BeamSearch(model=model, k=wandb.config.beam_width)
        beam_search.evaluate(subset, batch_size=100, use_wandb=True)
    wandb.finish()
# Out:
# Error in callback <bound method _WandbInit._pre_run_cell_hook of <wandb.sdk.wandb_init._WandbInit object at 0x7edd68a78c50>> (for pre_run_cell):
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/wandb_init.py in _pre_run_cell_hook(self, *args, **kwargs)
#     601         if self.backend.interface is not None:
#     602             self._logger.info("pausing backend")
# --> 603             self.backend.interface.publish_pause()
#     604
#     605     def _post_run_cell_hook(self, *args, **kwargs) -> None:
#
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/interface/interface.py in publish_pause(self)
#     768     def publish_pause(self) -> None:
#     769         pause = pb.PauseRequest()
# --> 770         self._publish_pause(pause)
#     771
#     772     @abstractmethod
#
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/interface/interface_shared.py in _publish_pause(self, pause)
#     287     def _publish_pause(self, pause: pb.PauseRequest) -> None:
#     288         rec = self._make_request(pause=pause)
# --> 289         self._publish(rec)
#     290
#     291     def _publish_resume(self, resume: pb.ResumeRequest) -> None:
#
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/interface/interface_sock.py in _publish(self, record, local)
#      37     def _publish(self, record: "pb.Record", local: Optional[bool] = None) -> None:
#      38         self._assign(record)
# ---> 39         self._sock_client.send_record_publish(record)
#
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/lib/sock_client.py in send_record_publish(self, record)
#     172         server_req.request_id = record.control.mailbox_slot
#     173         server_req.record_publish.CopyFrom(record)
# --> 174         self.send_server_request(server_req)
#     175
#     176     def _extract_packet_bytes(self) -> Optional[bytes]:
#
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/lib/sock_client.py in send_server_request(self, msg)
#     152
#     153     def send_server_request(self, msg: spb.ServerRequest) -> None:
# --> 154         self._send_message(msg)
#     155
#     156     def send_server_response(self, msg: spb.ServerResponse) -> None:
#
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/lib/sock_client.py in _send_message(self, msg)
#     149         header = struct.pack("<BI", ord("W"), raw_size)
#     150         with self._lock:
# --> 151             self._sendall_with_error_handle(header + data)
#     152
#     153     def send_server_request(self, msg: spb.ServerRequest) -> None:
#
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/lib/sock_client.py in _sendall_with_error_handle(self, data)
#     128             start_time = time.monotonic()
#     129             try:
# --> 130                 sent = self._sock.send(data)
#     131                 # sent equal to 0 indicates a closed socket
#     132                 if sent == 0:
#
# BrokenPipeError: [Errno 32] Broken pipe
# Error in callback <bound method _WandbInit._post_run_cell_hook of <wandb.sdk.wandb_init._WandbInit object at 0x7edd68a78c50>> (for post_run_cell):
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/wandb_init.py in _post_run_cell_hook(self, *args, **kwargs)
#     612
#     613         self._logger.info("resuming backend")
# --> 614         self.backend.interface.publish_resume()
#     615
#     616     def _jupyter_teardown(self) -> None:
#
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/interface/interface.py in publish_resume(self)
#     776     def publish_resume(self) -> None:
#     777         resume = pb.ResumeRequest()
# --> 778         self._publish_resume(resume)
#     779
#     780     @abstractmethod
#
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/interface/interface_shared.py in _publish_resume(self, resume)
#     291     def _publish_resume(self, resume: pb.ResumeRequest) -> None:
#     292         rec = self._make_request(resume=resume)
# --> 293         self._publish(rec)
#     294
#     295     def _publish_run(self, run: pb.RunRecord) -> None:
#
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/interface/interface_sock.py in _publish(self, record, local)
#      37     def _publish(self, record: "pb.Record", local: Optional[bool] = None) -> None:
#      38         self._assign(record)
# ---> 39         self._sock_client.send_record_publish(record)
#
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/lib/sock_client.py in send_record_publish(self, record)
#     172         server_req.request_id = record.control.mailbox_slot
#     173         server_req.record_publish.CopyFrom(record)
# --> 174         self.send_server_request(server_req)
#     175
#     176     def _extract_packet_bytes(self) -> Optional[bytes]:
#
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/lib/sock_client.py in send_server_request(self, msg)
#     152
#     153     def send_server_request(self, msg: spb.ServerRequest) -> None:
# --> 154         self._send_message(msg)
#     155
#     156     def send_server_response(self, msg: spb.ServerResponse) -> None:
#
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/lib/sock_client.py in _send_message(self, msg)
#     149         header = struct.pack("<BI", ord("W"), raw_size)
#     150         with self._lock:
# --> 151             self._sendall_with_error_handle(header + data)
#     152
#     153     def send_server_request(self, msg: spb.ServerRequest) -> None:
#
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/lib/sock_client.py in _sendall_with_error_handle(self, data)
#     128             start_time = time.monotonic()
#     129             try:
# --> 130                 sent = self._sock.send(data)
#     131                 # sent equal to 0 indicates a closed socket
#     132                 if sent == 0:
#
# BrokenPipeError: [Errno 32] Broken pipe

# %% [markdown]
# # Sweeps without Attention

# %%
sweep_config = {
  "name": "Sweep 1- Assignment3",
  "method": "grid",
  "parameters": {
        "enc_dec_layers": {
           "values": [1, 2, 3]
        },
        "units": {
            "values": [64, 128, 256]
        },
        "layer_type": {
            "values": ["rnn", "gru", "lstm"]
        }
    }
}

# %%
sweep_id = wandb.sweep(sweep_config, project="transliteration-sweep")
# Out:
# Create sweep with ID: c43kuut9
# Sweep URL: https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/sweeps/c43kuut9

# %%
wandb.agent(sweep_id, function=lambda: train_with_wandb("hi"), count=1)
# Out:
# wandb: Agent Starting Run: pl09da8r with config:
# wandb: 	enc_dec_layers: 1
# wandb: 	layer_type: gru
# wandb: 	units: 256
# wandb: WARNING Ignoring ID z30n30h8 loaded due to resume='auto' because the run ID is set to pl09da8r.
# Ignoring project 'transliteration-sweep' when running a sweep.
# Tracking run with wandb version 0.19.11
# Run data is saved locally in <code>/content/wandb/run-20250518_133612-pl09da8r</code>
# Syncing run <strong><a href='https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/runs/pl09da8r' target="_blank">wobbly-sweep-3</a></strong> to <a href='https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/sweeps/c43kuut9' target="_blank">https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/sweeps/c43kuut9</a>
#  View project at <a href='https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep' target="_blank">https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep</a>
#  View sweep at <a href='https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/sweeps/c43kuut9' target="_blank">https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/sweeps/c43kuut9</a>
#  View run at <a href='https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/runs/pl09da8r' target="_blank">https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/runs/pl09da8r</a>
# ----------------------------------------------------------------------------------------------------
# EPOCH 0
#
# Training ...
# /usr/local/lib/python3.11/dist-packages/keras/src/optimizers/base_optimizer.py:774: UserWarning: Gradients do not exist for variables ['seed_generator/seed_generator_state', 'seed_generator_1/seed_generator_state'] when minimizing the loss. If using `model.compile()`, did you forget to provide a `loss` argument?
#   warnings.warn(
# Batch 1 Loss 3.9832
# Batch 100 Loss 1.0443
# Batch 200 Loss 0.9215
# Batch 300 Loss 0.9444
#
# Validating ...
#
# Train Loss: 1.0608 Train Accuracy: 68.0813 Validation Loss: 3.2011 Validation Accuracy: 41.7195
#
# Time taken for the epoch 159.2077
# ----------------------------------------------------------------------------------------------------
# EPOCH 1
#
# Training ...
#
# Batch 1 Loss 0.9090
# Batch 100 Loss 0.9288
# Batch 200 Loss 0.8584
# Batch 300 Loss 0.8678
#
# Validating ...
#
# Train Loss: 0.8584 Train Accuracy: 74.9796 Validation Loss: 2.7271 Validation Accuracy: 49.6223
#
# Time taken for the epoch 133.8904
# ----------------------------------------------------------------------------------------------------
# EPOCH 2
#
# Training ...
#
# Batch 1 Loss 0.8360
# Batch 100 Loss 0.8375
# Batch 200 Loss 0.7282
# Batch 300 Loss 0.7173
#
# Validating ...
#
# Train Loss: 0.7611 Train Accuracy: 76.6367 Validation Loss: 2.8074 Validation Accuracy: 52.3259
#
# Time taken for the epoch 132.8079
# ----------------------------------------------------------------------------------------------------
# EPOCH 3
#
# Training ...
#
# Batch 1 Loss 0.7137
# Batch 100 Loss 0.6998
# Batch 200 Loss 0.6490
# Batch 300 Loss 0.6283
#
# Validating ...
#
# Train Loss: 0.6500 Train Accuracy: 79.6146 Validation Loss: 2.5535 Validation Accuracy: 56.7476
#
# Time taken for the epoch 142.2018
# ----------------------------------------------------------------------------------------------------
# EPOCH 4
#
# Training ...
#
# Batch 1 Loss 0.6575
# Batch 100 Loss 0.5764
# Batch 200 Loss 0.5030
# Batch 300 Loss 0.4954
#
# Validating ...
#
# Train Loss: 0.5378 Train Accuracy: 82.6722 Validation Loss: 2.3721 Validation Accuracy: 61.0620
#
# Time taken for the epoch 135.6128
# ----------------------------------------------------------------------------------------------------
# EPOCH 5
#
# Training ...
#
# Batch 1 Loss 0.4873
# Batch 100 Loss 0.4308
# Batch 200 Loss 0.4563
# Batch 300 Loss 0.3855
#
# Validating ...
#
# Train Loss: 0.4366 Train Accuracy: 85.7952 Validation Loss: 2.3768 Validation Accuracy: 62.6140
#
# Time taken for the epoch 133.8020
# ----------------------------------------------------------------------------------------------------
# EPOCH 6
#
# Training ...
#
# Batch 1 Loss 0.3840
# Batch 100 Loss 0.3672
# Batch 200 Loss 0.3915
# Batch 300 Loss 0.3380
#
# Validating ...
#
# Train Loss: 0.3508 Train Accuracy: 88.4333 Validation Loss: 1.9322 Validation Accuracy: 69.1275
#
# Time taken for the epoch 131.9200
# ----------------------------------------------------------------------------------------------------
# EPOCH 7
#
# Training ...
#
# Batch 1 Loss 0.2767
# Batch 100 Loss 0.2780
# Batch 200 Loss 0.3042
# Batch 300 Loss 0.2677
#
# Validating ...
#
# Train Loss: 0.2858 Train Accuracy: 90.6134 Validation Loss: 1.8027 Validation Accuracy: 73.1692
#
# Time taken for the epoch 131.9937
# ----------------------------------------------------------------------------------------------------
# EPOCH 8
#
# Training ...
#
# Batch 1 Loss 0.2546
# Batch 100 Loss 0.2512
# Batch 200 Loss 0.2593
# Batch 300 Loss 0.2551
#
# Validating ...
#
# Train Loss: 0.2399 Train Accuracy: 92.1409 Validation Loss: 1.6944 Validation Accuracy: 75.6063
#
# Time taken for the epoch 131.6029
# ----------------------------------------------------------------------------------------------------
# EPOCH 9
#
# Training ...
#
# Batch 1 Loss 0.2308
# Batch 100 Loss 0.2103
# Batch 200 Loss 0.2049
# Batch 300 Loss 0.1877
#
# Validating ...
#
# Train Loss: 0.2078 Train Accuracy: 93.2785 Validation Loss: 1.7513 Validation Accuracy: 75.7997
#
# Time taken for the epoch 131.9910
# ----------------------------------------------------------------------------------------------------
# EPOCH 10
#
# Training ...
#
# Batch 1 Loss 0.1853
# Batch 100 Loss 0.1784
# Batch 200 Loss 0.1721
# Batch 300 Loss 0.1791
#
# Validating ...
#
# Train Loss: 0.1836 Train Accuracy: 94.0651 Validation Loss: 1.6408 Validation Accuracy: 77.5588
#
# Time taken for the epoch 131.7069
# ----------------------------------------------------------------------------------------------------
# EPOCH 11
#
# Training ...
#
# Batch 1 Loss 0.1724
# Batch 100 Loss 0.1465
# Batch 200 Loss 0.1757
# Batch 300 Loss 0.1533
#
# Validating ...
#
# Train Loss: 0.1641 Train Accuracy: 94.7055 Validation Loss: 1.6757 Validation Accuracy: 78.6761
#
# Time taken for the epoch 131.9957
# ----------------------------------------------------------------------------------------------------
# EPOCH 12
#
# Training ...
#
# Batch 1 Loss 0.1424
# Batch 100 Loss 0.1484
# Batch 200 Loss 0.1304
# Batch 300 Loss 0.1356
#
# Validating ...
#
# Train Loss: 0.1483 Train Accuracy: 95.2535 Validation Loss: 1.6974 Validation Accuracy: 78.8490
#
# Time taken for the epoch 132.0608
# ----------------------------------------------------------------------------------------------------
# EPOCH 13
#
# Training ...
#
# Batch 1 Loss 0.1315
# Batch 100 Loss 0.1316
# Batch 200 Loss 0.1424
# Batch 300 Loss 0.1530
#
# Validating ...
#
# Train Loss: 0.1353 Train Accuracy: 95.6263 Validation Loss: 1.6447 Validation Accuracy: 80.1679
#
# Time taken for the epoch 131.6386
# ----------------------------------------------------------------------------------------------------
# EPOCH 14
#
# Training ...
#
# Batch 1 Loss 0.1352
# Batch 100 Loss 0.1202
# Batch 200 Loss 0.1112
# Batch 300 Loss 0.1337
#
# Validating ...
#
# Train Loss: 0.1238 Train Accuracy: 96.0760 Validation Loss: 1.6841 Validation Accuracy: 79.4909
#
# Time taken for the epoch 131.8394
# ----------------------------------------------------------------------------------------------------
#
# Model trained successfully !!
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>dev_acc</td><td>▁▂▃▄▅▅▆▇▇▇█████</td></tr><tr><td>dev_loss</td><td>█▆▆▅▄▄▂▂▁▁▁▁▁▁▁</td></tr><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>train_acc</td><td>▁▃▃▄▅▅▆▇▇▇▇████</td></tr><tr><td>train_loss</td><td>█▆▆▅▄▃▃▂▂▂▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>dev_acc</td><td>0.79491</td></tr><tr><td>dev_loss</td><td>1.68409</td></tr><tr><td>epoch</td><td>14</td></tr><tr><td>train_acc</td><td>0.96076</td></tr><tr><td>train_loss</td><td>0.12378</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ed_64_layers_1_type_gru_units_256_dropout_0_attention_False_beam_3_tf_1</strong> at: <a href='https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/runs/pl09da8r' target="_blank">https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/runs/pl09da8r</a><br> View project at: <a href='https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep' target="_blank">https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_133612-pl09da8r/logs</code>

# %%
wandb.agent(sweep_id, function=lambda: train_with_wandb("hi"), count=2)
# Out:
# wandb: Agent Starting Run: cg3yl5mt with config:
# wandb: 	enc_dec_layers: 2
# wandb: 	layer_type: gru
# wandb: 	units: 128
# Ignoring project 'transliteration-sweep' when running a sweep.
# Tracking run with wandb version 0.19.11
# Run data is saved locally in <code>/content/wandb/run-20250518_142654-cg3yl5mt</code>
# Syncing run <strong><a href='https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/runs/cg3yl5mt' target="_blank">glad-sweep-5</a></strong> to <a href='https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/sweeps/c43kuut9' target="_blank">https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/sweeps/c43kuut9</a>
#  View project at <a href='https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep' target="_blank">https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep</a>
#  View sweep at <a href='https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/sweeps/c43kuut9' target="_blank">https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/sweeps/c43kuut9</a>
#  View run at <a href='https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/runs/cg3yl5mt' target="_blank">https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/runs/cg3yl5mt</a>
# ----------------------------------------------------------------------------------------------------
# EPOCH 0
#
# Training ...
# /usr/local/lib/python3.11/dist-packages/keras/src/optimizers/base_optimizer.py:774: UserWarning: Gradients do not exist for variables ['seed_generator/seed_generator_state', 'encoder/gru_1/gru_cell/kernel', 'encoder/gru_1/gru_cell/recurrent_kernel', 'encoder/gru_1/gru_cell/bias', 'seed_generator_1/seed_generator_state', 'seed_generator_2/seed_generator_state', 'seed_generator_3/seed_generator_state'] when minimizing the loss. If using `model.compile()`, did you forget to provide a `loss` argument?
#   warnings.warn(
# Batch 1 Loss 3.9853
# Batch 100 Loss 1.0464
# Batch 200 Loss 0.9655
# Batch 300 Loss 0.9306
#
# Validating ...
#
# Train Loss: 1.1244 Train Accuracy: 66.8887 Validation Loss: 2.6500 Validation Accuracy: 48.6306
#
# Time taken for the epoch 100.9791
# ----------------------------------------------------------------------------------------------------
# EPOCH 1
#
# Training ...
#
# Batch 1 Loss 0.9236
# Batch 100 Loss 0.8690
# Batch 200 Loss 0.8630
# Batch 300 Loss 0.8760
#
# Validating ...
#
# Train Loss: 0.8925 Train Accuracy: 74.0874 Validation Loss: 2.4558 Validation Accuracy: 52.3689
#
# Time taken for the epoch 63.2729
# ----------------------------------------------------------------------------------------------------
# EPOCH 2
#
# Training ...
#
# Batch 1 Loss 0.9193
# Batch 100 Loss 0.8692
# Batch 200 Loss 0.8701
# Batch 300 Loss 0.8743
#
# Validating ...
#
# Train Loss: 0.8545 Train Accuracy: 75.1097 Validation Loss: 2.4431 Validation Accuracy: 53.6923
#
# Time taken for the epoch 63.2144
# ----------------------------------------------------------------------------------------------------
# EPOCH 3
#
# Training ...
#
# Batch 1 Loss 0.8250
# Batch 100 Loss 0.8296
# Batch 200 Loss 0.8030
# Batch 300 Loss 0.7746
#
# Validating ...
#
# Train Loss: 0.8084 Train Accuracy: 76.0383 Validation Loss: 2.9274 Validation Accuracy: 49.8227
#
# Time taken for the epoch 63.1208
# ----------------------------------------------------------------------------------------------------
# EPOCH 4
#
# Training ...
#
# Batch 1 Loss 0.7345
# Batch 100 Loss 0.7337
# Batch 200 Loss 0.6932
# Batch 300 Loss 0.6593
#
# Validating ...
#
# Train Loss: 0.7240 Train Accuracy: 77.8254 Validation Loss: 3.2610 Validation Accuracy: 46.9574
#
# Time taken for the epoch 63.1799
# ----------------------------------------------------------------------------------------------------
# EPOCH 5
#
# Training ...
#
# Batch 1 Loss 0.6437
# Batch 100 Loss 0.6417
# Batch 200 Loss 0.6516
# Batch 300 Loss 0.5902
#
# Validating ...
#
# Train Loss: 0.6168 Train Accuracy: 80.4576 Validation Loss: 2.7281 Validation Accuracy: 56.0059
#
# Time taken for the epoch 62.9042
# ----------------------------------------------------------------------------------------------------
# EPOCH 6
#
# Training ...
#
# Batch 1 Loss 0.5604
# Batch 100 Loss 0.5383
# Batch 200 Loss 0.4946
# Batch 300 Loss 0.5110
#
# Validating ...
#
# Train Loss: 0.5074 Train Accuracy: 83.4575 Validation Loss: 2.4409 Validation Accuracy: 61.6041
#
# Time taken for the epoch 63.2656
# ----------------------------------------------------------------------------------------------------
# EPOCH 7
#
# Training ...
#
# Batch 1 Loss 0.4738
# Batch 100 Loss 0.4461
# Batch 200 Loss 0.3843
# Batch 300 Loss 0.3881
#
# Validating ...
#
# Train Loss: 0.4204 Train Accuracy: 86.3500 Validation Loss: 2.2846 Validation Accuracy: 65.1575
#
# Time taken for the epoch 63.0462
# ----------------------------------------------------------------------------------------------------
# EPOCH 8
#
# Training ...
#
# Batch 1 Loss 0.3786
# Batch 100 Loss 0.3962
# Batch 200 Loss 0.3736
# Batch 300 Loss 0.3108
#
# Validating ...
#
# Train Loss: 0.3524 Train Accuracy: 88.5747 Validation Loss: 2.1411 Validation Accuracy: 69.0755
#
# Time taken for the epoch 63.0539
# ----------------------------------------------------------------------------------------------------
# EPOCH 9
#
# Training ...
#
# Batch 1 Loss 0.3349
# Batch 100 Loss 0.3150
# Batch 200 Loss 0.2919
# Batch 300 Loss 0.2984
#
# Validating ...
#
# Train Loss: 0.3044 Train Accuracy: 90.1486 Validation Loss: 1.9672 Validation Accuracy: 72.9568
#
# Time taken for the epoch 62.9471
# ----------------------------------------------------------------------------------------------------
# EPOCH 10
#
# Training ...
#
# Batch 1 Loss 0.3327
# Batch 100 Loss 0.2544
# Batch 200 Loss 0.2636
# Batch 300 Loss 0.2601
#
# Validating ...
#
# Train Loss: 0.2712 Train Accuracy: 91.2494 Validation Loss: 1.8750 Validation Accuracy: 74.3216
#
# Time taken for the epoch 63.1679
# ----------------------------------------------------------------------------------------------------
# EPOCH 11
#
# Training ...
#
# Batch 1 Loss 0.2595
# Batch 100 Loss 0.2602
# Batch 200 Loss 0.2551
# Batch 300 Loss 0.2596
#
# Validating ...
#
# Train Loss: 0.2461 Train Accuracy: 92.0480 Validation Loss: 1.7779 Validation Accuracy: 76.1426
#
# Time taken for the epoch 63.3129
# ----------------------------------------------------------------------------------------------------
# EPOCH 12
#
# Training ...
#
# Batch 1 Loss 0.2538
# Batch 100 Loss 0.2330
# Batch 200 Loss 0.2032
# Batch 300 Loss 0.2743
#
# Validating ...
#
# Train Loss: 0.2267 Train Accuracy: 92.5779 Validation Loss: 1.8262 Validation Accuracy: 75.9623
#
# Time taken for the epoch 62.9877
# ----------------------------------------------------------------------------------------------------
# EPOCH 13
#
# Training ...
#
# Batch 1 Loss 0.2211
# Batch 100 Loss 0.1923
# Batch 200 Loss 0.1989
# Batch 300 Loss 0.2369
#
# Validating ...
#
# Train Loss: 0.2098 Train Accuracy: 93.1787 Validation Loss: 1.7212 Validation Accuracy: 78.0338
#
# Time taken for the epoch 62.7979
# ----------------------------------------------------------------------------------------------------
# EPOCH 14
#
# Training ...
#
# Batch 1 Loss 0.2056
# Batch 100 Loss 0.1853
# Batch 200 Loss 0.1994
# Batch 300 Loss 0.1819
#
# Validating ...
#
# Train Loss: 0.1966 Train Accuracy: 93.6187 Validation Loss: 1.7098 Validation Accuracy: 77.7052
#
# Time taken for the epoch 63.0964
# ----------------------------------------------------------------------------------------------------
#
# Model trained successfully !!
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>dev_acc</td><td>▁▂▃▂▁▃▄▅▆▇▇████</td></tr><tr><td>dev_loss</td><td>▅▄▄▆█▆▄▄▃▂▂▁▂▁▁</td></tr><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>train_acc</td><td>▁▃▃▃▄▅▅▆▇▇▇████</td></tr><tr><td>train_loss</td><td>█▆▆▆▅▄▃▃▂▂▂▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>dev_acc</td><td>0.77705</td></tr><tr><td>dev_loss</td><td>1.70979</td></tr><tr><td>epoch</td><td>14</td></tr><tr><td>train_acc</td><td>0.93619</td></tr><tr><td>train_loss</td><td>0.19656</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ed_64_layers_2_type_gru_units_128_dropout_0_attention_False_beam_3_tf_1</strong> at: <a href='https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/runs/cg3yl5mt' target="_blank">https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/runs/cg3yl5mt</a><br> View project at: <a href='https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep' target="_blank">https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_142654-cg3yl5mt/logs</code>
# wandb: Agent Starting Run: lyl34x0r with config:
# wandb: 	enc_dec_layers: 2
# wandb: 	layer_type: gru
# wandb: 	units: 256
# Ignoring project 'transliteration-sweep' when running a sweep.
# Tracking run with wandb version 0.19.11
# Run data is saved locally in <code>/content/wandb/run-20250518_144322-lyl34x0r</code>
# Syncing run <strong><a href='https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/runs/lyl34x0r' target="_blank">magic-sweep-6</a></strong> to <a href='https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/sweeps/c43kuut9' target="_blank">https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/sweeps/c43kuut9</a>
#  View project at <a href='https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep' target="_blank">https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep</a>
#  View sweep at <a href='https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/sweeps/c43kuut9' target="_blank">https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/sweeps/c43kuut9</a>
#  View run at <a href='https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/runs/lyl34x0r' target="_blank">https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/runs/lyl34x0r</a>
# ----------------------------------------------------------------------------------------------------
# EPOCH 0
#
# Training ...
# /usr/local/lib/python3.11/dist-packages/keras/src/optimizers/base_optimizer.py:774: UserWarning: Gradients do not exist for variables ['seed_generator/seed_generator_state', 'encoder/gru_1/gru_cell/kernel', 'encoder/gru_1/gru_cell/recurrent_kernel', 'encoder/gru_1/gru_cell/bias', 'seed_generator_1/seed_generator_state', 'seed_generator_2/seed_generator_state', 'seed_generator_3/seed_generator_state'] when minimizing the loss. If using `model.compile()`, did you forget to provide a `loss` argument?
#   warnings.warn(
# Batch 1 Loss 3.9946
# Batch 100 Loss 1.0435
# Batch 200 Loss 0.9430
# Batch 300 Loss 0.8906
#
# Validating ...
#
# Train Loss: 1.0896 Train Accuracy: 66.9440 Validation Loss: 2.6011 Validation Accuracy: 51.5312
#
# Time taken for the epoch 317.2716
# ----------------------------------------------------------------------------------------------------
# EPOCH 1
#
# Training ...
#
# Batch 1 Loss 0.9007
# Batch 100 Loss 0.8598
# Batch 200 Loss 0.8835
# Batch 300 Loss 0.8070
#
# Validating ...
#
# Train Loss: 0.8704 Train Accuracy: 74.4259 Validation Loss: 3.2346 Validation Accuracy: 47.3358
#
# Time taken for the epoch 280.1882
# ----------------------------------------------------------------------------------------------------
# EPOCH 2
#
# Training ...
#
# Batch 1 Loss 0.8105
# Batch 100 Loss 0.8086
# Batch 200 Loss 0.8081
# Batch 300 Loss 0.7340
#
# Validating ...
#
# Train Loss: 0.7622 Train Accuracy: 76.6160 Validation Loss: 3.0769 Validation Accuracy: 50.1256
#
# Time taken for the epoch 277.3245
# ----------------------------------------------------------------------------------------------------
# EPOCH 3
#
# Training ...
#
# Batch 1 Loss 0.7151
# Batch 100 Loss 0.6773
# Batch 200 Loss 0.6207

# %%
sweep_config2 = {
  "method": "grid",
  "parameters": {
        "enc_dec_layers": {
           "values": [2, 3]
        },
        "embedding_dim": {
            "values": [64, 128, 256]
        },
        "dropout": {
            "values": [0.2, 0.3]
        }
    }
}

# %%
sweep_id2 = wandb.sweep(sweep_config2, project="transliteration-sweep")

# %%
wandb.agent(sweep_id2, function=lambda: train_with_wandb("hi"))

# %%
sweep_config3 = {
  "method": "grid",
  "parameters": {

        "beam_width": {
            "values": [3, 5, 7]
        }
    }
}

# %%
sweep_id3 = wandb.sweep(sweep_config3, project="transliteration-sweep")

# %%
wandb.agent(sweep_id3, function=lambda: train_with_wandb("hi", test_beam_search=True))

# %%
sweep_config4 = {
  "method": "grid",
  "parameters": {
        "teacher_forcing_ratio": {
            "values": [0.3, 0.5, 0.7, 0.9]
        },
        "enc_dec_layers": {
            "values": [2]
        },
        "embedding_dim": {
            "values": [128]
        },
        "dropout": {
            "values": [0.2]
        }
    }
}

# %%
sweep_id4 = wandb.sweep(sweep_config4, project="transliteration-sweep")

# %%
wandb.agent(sweep_id4, function=lambda: train_with_wandb("hi"))

# %% [markdown]
# # Sweeps with Attention

# %%
sweep_config5 = {
  "name": "Attention Sweep - Assignment3",
  "description": "Hyperparameter sweep for Seq2Seq Model with Attention",
  "method": "grid",
  "parameters": {
        "enc_dec_layers": {
           "values": [1, 2, 3]
        },
        "units": {
            "values": [128, 256]
        },
        "dropout": {
            "values": [0, 0.2]
        },
        "attention": {
            "values": [True]
        }
    }
}

# %%
sweep_id5 = wandb.sweep(sweep_config5, project="transliteration-sweep")
# Out:
# Create sweep with ID: vuskod1z
# Sweep URL: https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/sweeps/vuskod1z

# %%
wandb.agent(sweep_id5, function=lambda: train_with_wandb("hi"), project="transliteration-sweep", count=1)
# Out:
# wandb: Agent Starting Run: gfut84dc with config:
# wandb: 	attention: True
# wandb: 	dropout: 0
# wandb: 	enc_dec_layers: 1
# wandb: 	units: 128
# Ignoring project 'transliteration-sweep' when running a sweep.
# Tracking run with wandb version 0.19.11
# Run data is saved locally in <code>/content/wandb/run-20250518_200850-gfut84dc</code>
# Syncing run <strong><a href='https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/runs/gfut84dc' target="_blank">swept-sweep-1</a></strong> to <a href='https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/sweeps/fae7zayp' target="_blank">https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/sweeps/fae7zayp</a>
#  View project at <a href='https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep' target="_blank">https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep</a>
#  View sweep at <a href='https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/sweeps/fae7zayp' target="_blank">https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/sweeps/fae7zayp</a>
#  View run at <a href='https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/runs/gfut84dc' target="_blank">https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/runs/gfut84dc</a>
# ----------------------------------------------------------------------------------------------------
# EPOCH 0
#
# Training ...
# /usr/local/lib/python3.11/dist-packages/keras/src/optimizers/base_optimizer.py:774: UserWarning: Gradients do not exist for variables ['seed_generator/seed_generator_state', 'seed_generator_1/seed_generator_state'] when minimizing the loss. If using `model.compile()`, did you forget to provide a `loss` argument?
#   warnings.warn(
# Batch 1 Loss 3.9859
# Batch 100 Loss 1.0368
# Batch 200 Loss 0.9672
# Batch 300 Loss 0.8585
#
# Validating ...
#
# Train Loss: 1.0776 Train Accuracy: 68.3020 Validation Loss: 2.1054 Validation Accuracy: 51.5491
#
# Time taken for the epoch 44.3891
# ----------------------------------------------------------------------------------------------------
# EPOCH 1
#
# Training ...
#
# Batch 1 Loss 0.9195
# Batch 100 Loss 0.8282
# Batch 200 Loss 0.8433
# Batch 300 Loss 0.7389
#
# Validating ...
#
# Train Loss: 0.8168 Train Accuracy: 75.1538 Validation Loss: 2.0641 Validation Accuracy: 55.5400
#
# Time taken for the epoch 14.6480
# ----------------------------------------------------------------------------------------------------
# EPOCH 2
#
# Training ...
#
# Batch 1 Loss 0.6982
# Batch 100 Loss 0.6199
# Batch 200 Loss 0.4978
# Batch 300 Loss 0.4406
#
# Validating ...
#
# Train Loss: 0.5599 Train Accuracy: 80.9502 Validation Loss: 1.5476 Validation Accuracy: 68.3534
#
# Time taken for the epoch 20.3544
# ----------------------------------------------------------------------------------------------------
# EPOCH 3
#
# Training ...
#
# Batch 1 Loss 0.4302
# Batch 100 Loss 0.3263
# Batch 200 Loss 0.2896
# Batch 300 Loss 0.2918
#
# Validating ...
#
# Train Loss: 0.3211 Train Accuracy: 88.9179 Validation Loss: 1.3574 Validation Accuracy: 75.1633
#
# Time taken for the epoch 15.0326
# ----------------------------------------------------------------------------------------------------
# EPOCH 4
#
# Training ...
#
# Batch 1 Loss 0.2515
# Batch 100 Loss 0.2468
# Batch 200 Loss 0.2108
# Batch 300 Loss 0.2304
#
# Validating ...
#
# Train Loss: 0.2316 Train Accuracy: 92.3604 Validation Loss: 1.1771 Validation Accuracy: 79.5372
#
# Time taken for the epoch 12.9365
# ----------------------------------------------------------------------------------------------------
# EPOCH 5
#
# Training ...
#
# Batch 1 Loss 0.1713
# Batch 100 Loss 0.1836
# Batch 200 Loss 0.1638
# Batch 300 Loss 0.1745
#
# Validating ...
#
# Train Loss: 0.1948 Train Accuracy: 93.5818 Validation Loss: 1.2031 Validation Accuracy: 80.8472
#
# Time taken for the epoch 20.8666
# ----------------------------------------------------------------------------------------------------
# EPOCH 6
#
# Training ...
#
# Batch 1 Loss 0.1801
# Batch 100 Loss 0.1764
# Batch 200 Loss 0.1620
# Batch 300 Loss 0.1514
#
# Validating ...
#
# Train Loss: 0.1738 Train Accuracy: 94.2354 Validation Loss: 1.1566 Validation Accuracy: 82.2066
#
# Time taken for the epoch 12.8310
# ----------------------------------------------------------------------------------------------------
# EPOCH 7
#
# Training ...
#
# Batch 1 Loss 0.1754
# Batch 100 Loss 0.1528
# Batch 200 Loss 0.1456
# Batch 300 Loss 0.1471
#
# Validating ...
#
# Train Loss: 0.1601 Train Accuracy: 94.7256 Validation Loss: 1.1429 Validation Accuracy: 82.4223
#
# Time taken for the epoch 12.8038
# ----------------------------------------------------------------------------------------------------
# EPOCH 8
#
# Training ...
#
# Batch 1 Loss 0.1717
# Batch 100 Loss 0.1722
# Batch 200 Loss 0.1502
# Batch 300 Loss 0.1480
#
# Validating ...
#
# Train Loss: 0.1496 Train Accuracy: 95.0121 Validation Loss: 1.1406 Validation Accuracy: 82.8954
#
# Time taken for the epoch 12.8321
# ----------------------------------------------------------------------------------------------------
# EPOCH 9
#
# Training ...
#
# Batch 1 Loss 0.1555
# Batch 100 Loss 0.1354
# Batch 200 Loss 0.1489
# Batch 300 Loss 0.1384
#
# Validating ...
#
# Train Loss: 0.1402 Train Accuracy: 95.3162 Validation Loss: 1.1515 Validation Accuracy: 83.4806
#
# Time taken for the epoch 12.7750
# ----------------------------------------------------------------------------------------------------
# EPOCH 10
#
# Training ...
#
# Batch 1 Loss 0.1328
# Batch 100 Loss 0.1169
# Batch 200 Loss 0.1674
# Batch 300 Loss 0.1425
#
# Validating ...
#
# Train Loss: 0.1322 Train Accuracy: 95.6245 Validation Loss: 1.1549 Validation Accuracy: 83.5279
#
# Time taken for the epoch 12.9099
# ----------------------------------------------------------------------------------------------------
# EPOCH 11
#
# Training ...
#
# Batch 1 Loss 0.1189
# Batch 100 Loss 0.1179
# Batch 200 Loss 0.1275
# Batch 300 Loss 0.1044
#
# Validating ...
#
# Train Loss: 0.1260 Train Accuracy: 95.8101 Validation Loss: 1.1515 Validation Accuracy: 83.9025
#
# Time taken for the epoch 12.8519
# ----------------------------------------------------------------------------------------------------
# EPOCH 12
#
# Training ...
#
# Batch 1 Loss 0.1131
# Batch 100 Loss 0.1185
# Batch 200 Loss 0.1074
# Batch 300 Loss 0.0970
#
# Validating ...
#
# Train Loss: 0.1195 Train Accuracy: 96.0292 Validation Loss: 1.1362 Validation Accuracy: 84.3435
#
# Time taken for the epoch 15.1305
# ----------------------------------------------------------------------------------------------------
# EPOCH 13
#
# Training ...
#
# Batch 1 Loss 0.1135
# Batch 100 Loss 0.1080
# Batch 200 Loss 0.1082
# Batch 300 Loss 0.1318
#
# Validating ...
#
# Train Loss: 0.1138 Train Accuracy: 96.1727 Validation Loss: 1.1749 Validation Accuracy: 83.9318
#
# Time taken for the epoch 12.7693
# ----------------------------------------------------------------------------------------------------
# EPOCH 14
#
# Training ...
#
# Batch 1 Loss 0.1174
# Batch 100 Loss 0.1103
# Batch 200 Loss 0.1342
# Batch 300 Loss 0.1245
#
# Validating ...
#
# Train Loss: 0.1093 Train Accuracy: 96.3982 Validation Loss: 1.1595 Validation Accuracy: 83.7894
#
# Time taken for the epoch 12.8401
# ----------------------------------------------------------------------------------------------------
#
# Model trained successfully !!
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>dev_acc</td><td>▁▂▅▆▇▇█████████</td></tr><tr><td>dev_loss</td><td>██▄▃▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>train_acc</td><td>▁▃▄▆▇▇▇████████</td></tr><tr><td>train_loss</td><td>█▆▄▃▂▂▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>dev_acc</td><td>0.83789</td></tr><tr><td>dev_loss</td><td>1.15949</td></tr><tr><td>epoch</td><td>14</td></tr><tr><td>train_acc</td><td>0.96398</td></tr><tr><td>train_loss</td><td>0.10932</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ed_64_layers_1_type_lstm_units_128_dropout_0_attention_True_beam_3_tf_1</strong> at: <a href='https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/runs/gfut84dc' target="_blank">https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/runs/gfut84dc</a><br> View project at: <a href='https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep' target="_blank">https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_200850-gfut84dc/logs</code>

# %%
wandb.agent(sweep_id5, function=lambda: train_with_wandb("hi", test_beam_search=True), project="transliteration-sweep", count=1)
# Out:
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# wandb: Agent Starting Run: u54ryqzt with config:
# wandb: 	attention: True
# wandb: 	dropout: 0
# wandb: 	enc_dec_layers: 1
# wandb: 	units: 256
# wandb: WARNING Ignoring ID d66cqbwj loaded due to resume='auto' because the run ID is set to u54ryqzt.
# Ignoring project 'transliteration-sweep' when running a sweep.
# Tracking run with wandb version 0.19.11
# Run data is saved locally in <code>/content/wandb/run-20250518_205005-u54ryqzt</code>
# Syncing run <strong><a href='https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/runs/u54ryqzt' target="_blank">sweepy-sweep-2</a></strong> to <a href='https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/sweeps/vuskod1z' target="_blank">https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/sweeps/vuskod1z</a>
#  View project at <a href='https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep' target="_blank">https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep</a>
#  View sweep at <a href='https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/sweeps/vuskod1z' target="_blank">https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/sweeps/vuskod1z</a>
#  View run at <a href='https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/runs/u54ryqzt' target="_blank">https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/runs/u54ryqzt</a>
# ----------------------------------------------------------------------------------------------------
# EPOCH 0
#
# Training ...
# /usr/local/lib/python3.11/dist-packages/keras/src/optimizers/base_optimizer.py:774: UserWarning: Gradients do not exist for variables ['seed_generator/seed_generator_state', 'seed_generator_1/seed_generator_state'] when minimizing the loss. If using `model.compile()`, did you forget to provide a `loss` argument?
#   warnings.warn(
# Batch 1 Loss 3.9897
# Batch 100 Loss 1.0122
# Batch 200 Loss 0.9526
# Batch 300 Loss 0.8710
#
# Validating ...
#
# Train Loss: 1.0407 Train Accuracy: 68.7086 Validation Loss: 2.1836 Validation Accuracy: 52.1585
#
# Time taken for the epoch 51.6383
# ----------------------------------------------------------------------------------------------------
# EPOCH 1
#
# Training ...
#
# Batch 1 Loss 0.8714
# Batch 100 Loss 0.7942
# Batch 200 Loss 0.7570
# Batch 300 Loss 0.6674
#
# Validating ...
#
# Train Loss: 0.7815 Train Accuracy: 75.8233 Validation Loss: 2.5469 Validation Accuracy: 51.9202
#
# Time taken for the epoch 25.3897
# ----------------------------------------------------------------------------------------------------
# EPOCH 2
#
# Training ...
#
# Batch 1 Loss 0.6711
# Batch 100 Loss 0.6048
# Batch 200 Loss 0.5692
# Batch 300 Loss 0.4666
#
# Validating ...
#
# Train Loss: 0.5497 Train Accuracy: 81.2008 Validation Loss: 1.9938 Validation Accuracy: 63.0731
#
# Time taken for the epoch 25.5400
# ----------------------------------------------------------------------------------------------------
# EPOCH 3
#
# Training ...
#
# Batch 1 Loss 0.3957
# Batch 100 Loss 0.3825
# Batch 200 Loss 0.3500
# Batch 300 Loss 0.3220
#
# Validating ...
#
# Train Loss: 0.3547 Train Accuracy: 87.6216 Validation Loss: 1.5313 Validation Accuracy: 72.6239
#
# Time taken for the epoch 25.2981
# ----------------------------------------------------------------------------------------------------
# EPOCH 4
#
# Training ...
#
# Batch 1 Loss 0.3110
# Batch 100 Loss 0.2597
# Batch 200 Loss 0.2210
# Batch 300 Loss 0.2218
#
# Validating ...
#
# Train Loss: 0.2475 Train Accuracy: 91.2850 Validation Loss: 1.3628 Validation Accuracy: 77.9937
#
# Time taken for the epoch 25.4082
# ----------------------------------------------------------------------------------------------------
# EPOCH 5
#
# Training ...
#
# Batch 1 Loss 0.2089
# Batch 100 Loss 0.1713
# Batch 200 Loss 0.1960
# Batch 300 Loss 0.1556
#
# Validating ...
#
# Train Loss: 0.1876 Train Accuracy: 93.5796 Validation Loss: 1.2869 Validation Accuracy: 80.1460
#
# Time taken for the epoch 25.5842
# ----------------------------------------------------------------------------------------------------
# EPOCH 6
#
# Training ...
#
# Batch 1 Loss 0.1560
# Batch 100 Loss 0.1624
# Batch 200 Loss 0.1335
# Batch 300 Loss 0.1430
#
# Validating ...
#
# Train Loss: 0.1552 Train Accuracy: 94.8038 Validation Loss: 1.2145 Validation Accuracy: 81.9945
#
# Time taken for the epoch 25.8618
# ----------------------------------------------------------------------------------------------------
# EPOCH 7
#
# Training ...
#
# Batch 1 Loss 0.1377
# Batch 100 Loss 0.1410
# Batch 200 Loss 0.1367
# Batch 300 Loss 0.1323
#
# Validating ...
#
# Train Loss: 0.1354 Train Accuracy: 95.5097 Validation Loss: 1.2413 Validation Accuracy: 81.9424
#
# Time taken for the epoch 25.9442
# ----------------------------------------------------------------------------------------------------
# EPOCH 8
#
# Training ...
#
# Batch 1 Loss 0.1333
# Batch 100 Loss 0.1155
# Batch 200 Loss 0.1151
# Batch 300 Loss 0.1210
#
# Validating ...
#
# Train Loss: 0.1199 Train Accuracy: 96.0194 Validation Loss: 1.2137 Validation Accuracy: 82.9631
#
# Time taken for the epoch 25.5439
# ----------------------------------------------------------------------------------------------------
# EPOCH 9
#
# Training ...
#
# Batch 1 Loss 0.1030
# Batch 100 Loss 0.1085
# Batch 200 Loss 0.1312
# Batch 300 Loss 0.0901
#
# Validating ...
#
# Train Loss: 0.1069 Train Accuracy: 96.5052 Validation Loss: 1.1914 Validation Accuracy: 83.9707
#
# Time taken for the epoch 25.4746
# ----------------------------------------------------------------------------------------------------
# EPOCH 10
#
# Training ...
#
# Batch 1 Loss 0.0895
# Batch 100 Loss 0.1031
# Batch 200 Loss 0.0774
# Batch 300 Loss 0.0950
#
# Validating ...
#
# Train Loss: 0.0965 Train Accuracy: 96.8572 Validation Loss: 1.2077 Validation Accuracy: 83.4164
#
# Time taken for the epoch 25.8423
# ----------------------------------------------------------------------------------------------------
# EPOCH 11
#
# Training ...
#
# Batch 1 Loss 0.0812
# Batch 100 Loss 0.0789
# Batch 200 Loss 0.1115
# Batch 300 Loss 0.0787
#
# Validating ...
#
# Train Loss: 0.0866 Train Accuracy: 97.1878 Validation Loss: 1.2832 Validation Accuracy: 82.8409
#
# Time taken for the epoch 25.6515
# ----------------------------------------------------------------------------------------------------
# EPOCH 12
#
# Training ...
#
# Batch 1 Loss 0.0661
# Batch 100 Loss 0.0694
# Batch 200 Loss 0.0669
# Batch 300 Loss 0.0770
#
# Validating ...
#
# Train Loss: 0.0779 Train Accuracy: 97.5575 Validation Loss: 1.2522 Validation Accuracy: 84.0156
#
# Time taken for the epoch 25.7732
# ----------------------------------------------------------------------------------------------------
# EPOCH 13
#
# Training ...
#
# Batch 1 Loss 0.0768
# Batch 100 Loss 0.0656
# Batch 200 Loss 0.0795
# Batch 300 Loss 0.0649
#
# Validating ...
#
# Train Loss: 0.0695 Train Accuracy: 97.7821 Validation Loss: 1.2390 Validation Accuracy: 84.1405
#
# Time taken for the epoch 25.2446
# ----------------------------------------------------------------------------------------------------
# EPOCH 14
#
# Training ...
#
# Batch 1 Loss 0.0616
# Batch 100 Loss 0.0573
# Batch 200 Loss 0.0653
# Batch 300 Loss 0.0809
#
# Validating ...
#
# Train Loss: 0.0626 Train Accuracy: 98.0384 Validation Loss: 1.2928 Validation Accuracy: 84.1256
#
# Time taken for the epoch 25.2134
# ----------------------------------------------------------------------------------------------------
# EPOCH 15
#
# Training ...
#
# Batch 1 Loss 0.0596
# Batch 100 Loss 0.0510
# Batch 200 Loss 0.0441
# Batch 300 Loss 0.0573
#
# Validating ...
#
# Train Loss: 0.0564 Train Accuracy: 98.2420 Validation Loss: 1.3362 Validation Accuracy: 83.8951
#
# Time taken for the epoch 25.6387
# ----------------------------------------------------------------------------------------------------
# EPOCH 16
#
# Training ...
#
# Batch 1 Loss 0.0358
# Batch 100 Loss 0.0541
# Batch 200 Loss 0.0444
# Batch 300 Loss 0.0601
#
# Validating ...
#
# Train Loss: 0.0511 Train Accuracy: 98.4147 Validation Loss: 1.3707 Validation Accuracy: 84.2448
#
# Time taken for the epoch 25.1765
# ----------------------------------------------------------------------------------------------------
# EPOCH 17
#
# Training ...
#
# Batch 1 Loss 0.0394
# Batch 100 Loss 0.0406
# Batch 200 Loss 0.0477
# Batch 300 Loss 0.0347
#
# Validating ...
#
# Train Loss: 0.0452 Train Accuracy: 98.6086 Validation Loss: 1.4076 Validation Accuracy: 84.2012
#
# Time taken for the epoch 25.3212
# ----------------------------------------------------------------------------------------------------
# EPOCH 18
#
# Training ...
#
# Batch 1 Loss 0.0369
# Batch 100 Loss 0.0398
# Batch 200 Loss 0.0383
# Batch 300 Loss 0.0462
#
# Validating ...
#
# Train Loss: 0.0415 Train Accuracy: 98.7368 Validation Loss: 1.4505 Validation Accuracy: 84.0747
#
# Time taken for the epoch 25.2422
# ----------------------------------------------------------------------------------------------------
# EPOCH 19
#
# Training ...
#
# Batch 1 Loss 0.0363
# Batch 100 Loss 0.0317
# Batch 200 Loss 0.0369
# Batch 300 Loss 0.0557
#
# Validating ...
#
# Train Loss: 0.0377 Train Accuracy: 98.8510 Validation Loss: 1.4815 Validation Accuracy: 83.5815
#
# Time taken for the epoch 25.0256
# ----------------------------------------------------------------------------------------------------
#
# Model trained successfully !!
#
# Running test dataset through the model...
#
# Test Loss: 1.5041 Test Accuracy: 0.8356
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>dev_acc</td><td>▁▁▃▅▇▇██████████████</td></tr><tr><td>dev_loss</td><td>▆█▅▃▂▁▁▁▁▁▁▁▁▁▂▂▂▂▂▂</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>test acc</td><td>▁</td></tr><tr><td>train_acc</td><td>▁▃▄▅▆▇▇▇▇▇██████████</td></tr><tr><td>train_loss</td><td>█▆▅▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>dev_acc</td><td>0.83581</td></tr><tr><td>dev_loss</td><td>1.48149</td></tr><tr><td>epoch</td><td>19</td></tr><tr><td>test acc</td><td>0.83561</td></tr><tr><td>train_acc</td><td>0.98851</td></tr><tr><td>train_loss</td><td>0.03772</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ed_64_layers_1_type_lstm_units_256_dropout_0_attention_True_beam_3_tf_1</strong> at: <a href='https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/runs/u54ryqzt' target="_blank">https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep/runs/u54ryqzt</a><br> View project at: <a href='https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep' target="_blank">https://wandb.ai/ma23c011-indian-institute-of-technology-madras/transliteration-sweep</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_205005-u54ryqzt/logs</code>
# wandb: ERROR Run u54ryqzt errored:
# wandb: ERROR Traceback (most recent call last):
# wandb: ERROR   File "/usr/local/lib/python3.11/dist-packages/wandb/agents/pyagent.py", line 306, in _run_job
# wandb: ERROR     self._function()
# wandb: ERROR   File "<ipython-input-22-c015c399e45d>", line 1, in <lambda>
# wandb: ERROR     wandb.agent(sweep_id5, function=lambda: train_with_wandb("hi", test_beam_search=True), project="transliteration-sweep", count=1)
# wandb: ERROR                                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# wandb: ERROR   File "<ipython-input-21-82ecbe89394e>", line 54, in train_with_wandb
# wandb: ERROR     beam_search.evaluate(subset, batch_size=100, use_wandb=True)
# wandb: ERROR   File "<ipython-input-9-2e0a4b6a334e>", line 80, in evaluate
# wandb: ERROR     _, acc = self.step(input, target, enc_state)
# wandb: ERROR              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# wandb: ERROR   File "<ipython-input-9-2e0a4b6a334e>", line 60, in step
# wandb: ERROR     possibilities, scores = self.sample_beam_search(sequences[i, :, :])
# wandb: ERROR                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# wandb: ERROR   File "<ipython-input-9-2e0a4b6a334e>", line 18, in sample_beam_search
# wandb: ERROR     new_beam = [seq + [j], score - tf.math.log(row[j])]
# wandb: ERROR                                                ~~~^^^
# wandb: ERROR   File "/usr/local/lib/python3.11/dist-packages/tensorflow/python/util/traceback_utils.py", line 153, in error_handler
# wandb: ERROR     raise e.with_traceback(filtered_tb) from None
# wandb: ERROR   File "/usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/ops.py", line 6002, in raise_from_not_ok_status
# wandb: ERROR     raise core._status_to_exception(e) from None  # pylint: disable=protected-access
# wandb: ERROR     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# wandb: ERROR tensorflow.python.framework.errors_impl.InvalidArgumentError: {{function_node __wrapped__StridedSlice_device_/job:localhost/replica:0/task:0/device:GPU:0}} slice index 16 of dimension 0 out of bounds. [Op:StridedSlice] name: strided_slice/
# wandb: ERROR
# Error in callback <bound method _WandbInit._post_run_cell_hook of <wandb.sdk.wandb_init._WandbInit object at 0x7edd68a78c50>> (for post_run_cell):
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/wandb_init.py in _post_run_cell_hook(self, *args, **kwargs)
#     612
#     613         self._logger.info("resuming backend")
# --> 614         self.backend.interface.publish_resume()
#     615
#     616     def _jupyter_teardown(self) -> None:
#
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/interface/interface.py in publish_resume(self)
#     776     def publish_resume(self) -> None:
#     777         resume = pb.ResumeRequest()
# --> 778         self._publish_resume(resume)
#     779
#     780     @abstractmethod
#
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/interface/interface_shared.py in _publish_resume(self, resume)
#     291     def _publish_resume(self, resume: pb.ResumeRequest) -> None:
#     292         rec = self._make_request(resume=resume)
# --> 293         self._publish(rec)
#     294
#     295     def _publish_run(self, run: pb.RunRecord) -> None:
#
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/interface/interface_sock.py in _publish(self, record, local)
#      37     def _publish(self, record: "pb.Record", local: Optional[bool] = None) -> None:
#      38         self._assign(record)
# ---> 39         self._sock_client.send_record_publish(record)
#
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/lib/sock_client.py in send_record_publish(self, record)
#     172         server_req.request_id = record.control.mailbox_slot
#     173         server_req.record_publish.CopyFrom(record)
# --> 174         self.send_server_request(server_req)
#     175
#     176     def _extract_packet_bytes(self) -> Optional[bytes]:
#
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/lib/sock_client.py in send_server_request(self, msg)
#     152
#     153     def send_server_request(self, msg: spb.ServerRequest) -> None:
# --> 154         self._send_message(msg)
#     155
#     156     def send_server_response(self, msg: spb.ServerResponse) -> None:
#
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/lib/sock_client.py in _send_message(self, msg)
#     149         header = struct.pack("<BI", ord("W"), raw_size)
#     150         with self._lock:
# --> 151             self._sendall_with_error_handle(header + data)
#     152
#     153     def send_server_request(self, msg: spb.ServerRequest) -> None:
#
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/lib/sock_client.py in _sendall_with_error_handle(self, data)
#     128             start_time = time.monotonic()
#     129             try:
# --> 130                 sent = self._sock.send(data)
#     131                 # sent equal to 0 indicates a closed socket
#     132                 if sent == 0:
#
# BrokenPipeError: [Errno 32] Broken pipe

# %%
wandb.agent(sweep_id5, function=lambda: train_with_wandb("hi", test_beam_search=True), project="transliteration-sweep", count=1)
